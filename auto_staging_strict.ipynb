# %%
import pandas as pd
from openai import OpenAI
import os
import json
from dotenv import load_dotenv

# Constants
INPUT_FILE = 'dublette_cleaned_results_final.xlsx'
OUTPUT_FILE = 'processed_results_detailed.xlsx'
OPENAI_MODEL = 'gpt-4o'
MAX_ROWS = 500  # Number of entries to process
load_dotenv()
# Instantiate the OpenAI client
client = OpenAI(api_key=os.getenv('OPENAI_APIKEY'))  # You can omit the api_key if it's set in your environment

PROMPT_TEMPLATE = '''
You are assisting in categorizing the potential value of a paper based on its title and abstract. The objective is to identify papers that contribute to one the following research focus areas:

1. **User or Stakeholder Requirements**: Papers should provide insights into the requirements for AI-based knowledge management/retrieval systems. This includes user needs, stakeholder expectations, or technical necessities like data organization, system performance, UX design, or interaction features. The focus should be on systems that handle **internal knowledge sources** and ideally on conversational or retrieval solutions.

2. **Design Principles and Acceptance Requirements**: Papers should discuss design principles, frameworks, or approaches that support successful implementation of such systems. This includes considerations for usability, system integration, or factors impacting user acceptance. But related to the previous point at best

Evaluate the relevance of each paper critically and categorize it into one of the following stages:

- **NOT_RELEVANT**: The paper does not address the research focus areas. Examples include papers about unrelated use cases, outdated methods, or overly narrow topics without transferable insights.
- **MAYBE_RELEVANT**: The paper potentially addresses one or more research focus areas. It warrants a closer review but lacks clear evidence in the title/abstract.
- **RELEVANT**: The paper clearly aligns with one or both focus areas, providing substantial or promising insights.
- **NOT_FOUND**: No abstract was provided or no successful request/response occurred.

Provide your response in plain JSON format to enable direct processing, including a brief justification. For example:

{{
  "CATEGORY": "RELEVANT",
  "REASON": "The abstract highlights user-centered design principles and discusses AI integration in knowledge retrieval systems."
}}

Be critical in your evaluation. If the paper does not explicitly or implicitly addresses on of the points, it should be classified as NOT_RELEVANT. 
  
Title: {Title}
Abstract: {Abstract}
'''



# Function to process each paper
def categorize_paper(title: str, abstract: str):
    if pd.isna(abstract) or abstract.strip() == '' or abstract.strip().upper() == 'NOT_FOUND':
        return 'NOT_FOUND', 'No abstract was found / no successful request or response.'

    prompt = PROMPT_TEMPLATE.format(Title=title, Abstract=abstract)

    try:
        response = client.chat.completions.create(
            model=OPENAI_MODEL,
            messages=[
                {"role": "user", "content": prompt}
            ],
            max_tokens=150,
            n=1,
            temperature=0.0,
            response_format={"type": "json_object"}
        )
        reply = response.choices[0].message.content
        result = json.loads(reply)
        category = result.get('CATEGORY', 'NOT_FOUND')
        reason = result.get('REASON', '')
    except json.JSONDecodeError:
        category = 'NOT_FOUND'
        reason = 'Could not parse the response as JSON.'
    except Exception as e:
        category = 'NOT_FOUND'
        reason = f'Error during API call: {str(e)}'
        print(reason)

    return category, reason


# Main processing function
def process_papers():
    # Load the data
    df = pd.read_excel(INPUT_FILE)

    # Check and add columns if they don't already exist
    if 'GPT_STAGING' not in df.columns:
        df.insert(0, 'GPT_STAGING', '')
    else:
        print("Column 'GPT_STAGING' already exists.")

    if 'REASON' not in df.columns:
        df.insert(1, 'REASON', '')
    else:
        print("Column 'REASON' already exists.")

    # Process each paper
    for idx, row in df.head(MAX_ROWS).iterrows():
        # Skip if GPT_STAGING is already filled with some value
        title = row['Title']
        abstract = row['Abstract']
        category, reason = categorize_paper(title, abstract)
        df.at[idx, 'GPT_STAGING'] = category
        df.at[idx, 'REASON'] = reason
        print(f'Processed paper {idx + 1}/{MAX_ROWS}: {category}')

    # Save the results
    df.to_excel(OUTPUT_FILE, index=False)
    print(f'\nProcessing complete. Results saved to {OUTPUT_FILE}')

# %%
# Process the papers
process_papers()
# Out:
# Processed paper 1/500: NOT_RELEVANT
# Processed paper 2/500: NOT_RELEVANT
# Processed paper 3/500: NOT_RELEVANT
# Processed paper 4/500: NOT_RELEVANT
# Processed paper 5/500: NOT_RELEVANT
# Processed paper 6/500: NOT_RELEVANT
# Processed paper 7/500: NOT_RELEVANT
# Processed paper 8/500: MAYBE_RELEVANT
# Processed paper 9/500: NOT_RELEVANT
# Processed paper 10/500: NOT_RELEVANT
# Processed paper 11/500: MAYBE_RELEVANT
# Processed paper 12/500: NOT_RELEVANT
# Processed paper 13/500: NOT_RELEVANT
# Processed paper 14/500: NOT_RELEVANT
# Processed paper 15/500: NOT_RELEVANT
# Processed paper 16/500: NOT_RELEVANT
# Processed paper 17/500: NOT_RELEVANT
# Processed paper 18/500: NOT_RELEVANT
# Processed paper 19/500: NOT_RELEVANT
# Processed paper 20/500: NOT_RELEVANT
# Processed paper 21/500: NOT_RELEVANT
# Processed paper 22/500: NOT_RELEVANT
# Processed paper 23/500: NOT_RELEVANT
# Processed paper 24/500: NOT_RELEVANT
# Processed paper 25/500: NOT_RELEVANT
# Processed paper 26/500: NOT_RELEVANT
# Processed paper 27/500: NOT_RELEVANT
# Processed paper 28/500: NOT_RELEVANT
# Processed paper 29/500: NOT_RELEVANT
# Processed paper 30/500: NOT_RELEVANT
# Processed paper 31/500: NOT_RELEVANT
# Processed paper 32/500: NOT_RELEVANT
# Processed paper 33/500: NOT_RELEVANT
# Processed paper 34/500: NOT_RELEVANT
# Processed paper 35/500: NOT_RELEVANT
# Processed paper 36/500: NOT_RELEVANT
# Processed paper 37/500: NOT_RELEVANT
# Processed paper 38/500: NOT_RELEVANT
# Processed paper 39/500: NOT_RELEVANT
# Processed paper 40/500: NOT_RELEVANT
# Processed paper 41/500: NOT_RELEVANT
# Processed paper 42/500: NOT_RELEVANT
# Processed paper 43/500: NOT_RELEVANT
# Processed paper 44/500: MAYBE_RELEVANT
# Processed paper 45/500: NOT_RELEVANT
# Processed paper 46/500: NOT_RELEVANT
# Processed paper 47/500: NOT_RELEVANT
# Processed paper 48/500: NOT_RELEVANT
# Processed paper 49/500: NOT_RELEVANT
# Processed paper 50/500: NOT_RELEVANT
# Processed paper 51/500: NOT_RELEVANT
# Processed paper 52/500: NOT_RELEVANT
# Processed paper 53/500: NOT_RELEVANT
# Processed paper 54/500: NOT_RELEVANT
# Processed paper 55/500: NOT_RELEVANT
# Processed paper 56/500: NOT_RELEVANT
# Processed paper 57/500: NOT_RELEVANT
# Processed paper 58/500: NOT_RELEVANT
# Processed paper 59/500: NOT_RELEVANT
# Processed paper 60/500: NOT_RELEVANT
# Processed paper 61/500: NOT_RELEVANT
# Processed paper 62/500: NOT_RELEVANT
# Processed paper 63/500: NOT_RELEVANT
# Processed paper 64/500: NOT_RELEVANT
# Processed paper 65/500: NOT_RELEVANT
# Processed paper 66/500: NOT_RELEVANT
# Processed paper 67/500: NOT_RELEVANT
# Processed paper 68/500: NOT_RELEVANT
# Processed paper 69/500: MAYBE_RELEVANT
# Processed paper 70/500: NOT_RELEVANT
# Processed paper 71/500: NOT_RELEVANT
# Processed paper 72/500: NOT_RELEVANT
# Processed paper 73/500: MAYBE_RELEVANT
# Processed paper 74/500: NOT_RELEVANT
# Processed paper 75/500: NOT_RELEVANT
# Processed paper 76/500: NOT_RELEVANT
# Processed paper 77/500: NOT_RELEVANT
# Processed paper 78/500: NOT_RELEVANT
# Processed paper 79/500: NOT_RELEVANT
# Processed paper 80/500: NOT_RELEVANT
# Processed paper 81/500: NOT_RELEVANT
# Processed paper 82/500: NOT_RELEVANT
# Processed paper 83/500: NOT_RELEVANT
# Processed paper 84/500: MAYBE_RELEVANT
# Processed paper 85/500: NOT_RELEVANT
# Processed paper 86/500: MAYBE_RELEVANT
# Processed paper 87/500: NOT_RELEVANT
# Processed paper 88/500: NOT_RELEVANT
# Processed paper 89/500: MAYBE_RELEVANT
# Processed paper 90/500: NOT_RELEVANT
# Processed paper 91/500: NOT_RELEVANT
# Processed paper 92/500: NOT_RELEVANT
# Processed paper 93/500: NOT_RELEVANT
# Processed paper 94/500: NOT_RELEVANT
# Processed paper 95/500: NOT_RELEVANT
# Processed paper 96/500: NOT_RELEVANT
# Processed paper 97/500: NOT_RELEVANT
# Processed paper 98/500: NOT_RELEVANT
# Processed paper 99/500: NOT_RELEVANT
# Processed paper 100/500: NOT_RELEVANT
# Processed paper 101/500: NOT_RELEVANT
# Processed paper 102/500: NOT_RELEVANT
# Processed paper 103/500: NOT_RELEVANT
# Processed paper 104/500: NOT_RELEVANT
# Processed paper 105/500: NOT_RELEVANT
# Processed paper 106/500: NOT_RELEVANT
# Processed paper 107/500: NOT_RELEVANT
# Processed paper 108/500: NOT_RELEVANT
# Processed paper 109/500: NOT_RELEVANT
# Processed paper 110/500: NOT_RELEVANT
# Processed paper 111/500: NOT_RELEVANT
# Processed paper 112/500: NOT_RELEVANT
# Processed paper 113/500: NOT_RELEVANT
# Processed paper 114/500: NOT_RELEVANT
# Processed paper 115/500: NOT_RELEVANT
# Processed paper 116/500: MAYBE_RELEVANT
# Processed paper 117/500: NOT_RELEVANT
# Processed paper 118/500: NOT_RELEVANT
# Processed paper 119/500: NOT_RELEVANT
# Processed paper 120/500: MAYBE_RELEVANT
# Processed paper 121/500: NOT_RELEVANT
# Processed paper 122/500: NOT_RELEVANT
# Processed paper 123/500: NOT_RELEVANT
# Processed paper 124/500: NOT_RELEVANT
# Processed paper 125/500: NOT_RELEVANT
# Processed paper 126/500: MAYBE_RELEVANT
# Processed paper 127/500: NOT_RELEVANT
# Processed paper 128/500: NOT_RELEVANT
# Processed paper 129/500: NOT_RELEVANT
# Processed paper 130/500: NOT_RELEVANT
# Processed paper 131/500: NOT_RELEVANT
# Processed paper 132/500: NOT_RELEVANT
# Processed paper 133/500: NOT_RELEVANT
# Processed paper 134/500: NOT_RELEVANT
# Processed paper 135/500: NOT_RELEVANT
# Processed paper 136/500: NOT_RELEVANT
# Processed paper 137/500: NOT_RELEVANT
# Processed paper 138/500: NOT_RELEVANT
# Processed paper 139/500: NOT_RELEVANT
# Processed paper 140/500: NOT_RELEVANT
# Processed paper 141/500: NOT_RELEVANT
# Processed paper 142/500: NOT_RELEVANT
# Processed paper 143/500: NOT_RELEVANT
# Processed paper 144/500: NOT_RELEVANT
# Processed paper 145/500: NOT_RELEVANT
# Processed paper 146/500: MAYBE_RELEVANT
# Processed paper 147/500: NOT_RELEVANT
# Processed paper 148/500: NOT_RELEVANT
# Processed paper 149/500: NOT_RELEVANT
# Processed paper 150/500: NOT_RELEVANT
# Processed paper 151/500: NOT_RELEVANT
# Processed paper 152/500: NOT_RELEVANT
# Processed paper 153/500: NOT_RELEVANT
# Processed paper 154/500: NOT_RELEVANT
# Processed paper 155/500: NOT_RELEVANT
# Processed paper 156/500: NOT_RELEVANT
# Processed paper 157/500: NOT_RELEVANT
# Processed paper 158/500: NOT_RELEVANT
# Processed paper 159/500: NOT_RELEVANT
# Processed paper 160/500: MAYBE_RELEVANT
# Processed paper 161/500: NOT_RELEVANT
# Processed paper 162/500: NOT_RELEVANT
# Processed paper 163/500: NOT_RELEVANT
# Processed paper 164/500: NOT_RELEVANT
# Processed paper 165/500: NOT_RELEVANT
# Processed paper 166/500: NOT_RELEVANT
# Processed paper 167/500: NOT_RELEVANT
# Processed paper 168/500: NOT_RELEVANT
# Processed paper 169/500: NOT_RELEVANT
# Processed paper 170/500: NOT_RELEVANT
# Processed paper 171/500: NOT_RELEVANT
# Processed paper 172/500: NOT_RELEVANT
# Processed paper 173/500: NOT_RELEVANT
# Processed paper 174/500: NOT_RELEVANT
# Processed paper 175/500: NOT_RELEVANT
# Processed paper 176/500: NOT_RELEVANT
# Processed paper 177/500: NOT_RELEVANT
# Processed paper 178/500: NOT_RELEVANT
# Processed paper 179/500: NOT_RELEVANT
# Processed paper 180/500: NOT_RELEVANT
# Processed paper 181/500: NOT_RELEVANT
# Processed paper 182/500: NOT_RELEVANT
# Processed paper 183/500: NOT_RELEVANT
# Processed paper 184/500: NOT_RELEVANT
# Processed paper 185/500: NOT_RELEVANT
# Processed paper 186/500: NOT_RELEVANT
# Processed paper 187/500: NOT_RELEVANT
# Processed paper 188/500: NOT_RELEVANT
# Processed paper 189/500: NOT_RELEVANT
# Processed paper 190/500: NOT_RELEVANT
# Processed paper 191/500: MAYBE_RELEVANT
# Processed paper 192/500: NOT_RELEVANT
# Processed paper 193/500: MAYBE_RELEVANT
# Processed paper 194/500: NOT_RELEVANT
# Processed paper 195/500: NOT_RELEVANT
# Processed paper 196/500: NOT_RELEVANT
# Processed paper 197/500: NOT_RELEVANT
# Processed paper 198/500: MAYBE_RELEVANT
# Processed paper 199/500: NOT_RELEVANT
# Processed paper 200/500: NOT_RELEVANT
# Processed paper 201/500: NOT_FOUND
# Processed paper 202/500: NOT_FOUND
# Processed paper 203/500: NOT_FOUND
# Processed paper 204/500: NOT_FOUND
# Processed paper 205/500: NOT_FOUND
# Processed paper 206/500: NOT_FOUND
# Processed paper 207/500: NOT_FOUND
# Processed paper 208/500: NOT_FOUND
# Processed paper 209/500: NOT_FOUND
# Processed paper 210/500: NOT_FOUND
# Processed paper 211/500: NOT_FOUND
# Processed paper 212/500: NOT_FOUND
# Processed paper 213/500: NOT_FOUND
# Processed paper 214/500: NOT_FOUND
# Processed paper 215/500: NOT_FOUND
# Processed paper 216/500: NOT_FOUND
# Processed paper 217/500: NOT_FOUND
# Processed paper 218/500: NOT_FOUND
# Processed paper 219/500: NOT_FOUND
# Processed paper 220/500: NOT_FOUND
# Processed paper 221/500: NOT_FOUND
# Processed paper 222/500: NOT_FOUND
# Processed paper 223/500: NOT_FOUND
# Processed paper 224/500: NOT_FOUND
# Processed paper 225/500: NOT_FOUND
# Processed paper 226/500: NOT_FOUND
# Processed paper 227/500: NOT_FOUND
# Processed paper 228/500: NOT_FOUND
# Processed paper 229/500: NOT_FOUND
# Processed paper 230/500: NOT_FOUND
# Processed paper 231/500: NOT_FOUND
# Processed paper 232/500: NOT_FOUND
# Processed paper 233/500: NOT_FOUND
# Processed paper 234/500: NOT_FOUND
# Processed paper 235/500: NOT_FOUND
# Processed paper 236/500: NOT_FOUND
# Processed paper 237/500: NOT_RELEVANT
# Processed paper 238/500: NOT_RELEVANT
# Processed paper 239/500: NOT_RELEVANT
# Processed paper 240/500: NOT_RELEVANT
# Processed paper 241/500: RELEVANT
# Processed paper 242/500: NOT_RELEVANT
# Processed paper 243/500: NOT_RELEVANT
# Processed paper 244/500: MAYBE_RELEVANT
# Processed paper 245/500: NOT_RELEVANT
# Processed paper 246/500: MAYBE_RELEVANT
# Processed paper 247/500: NOT_RELEVANT
# Processed paper 248/500: MAYBE_RELEVANT
# Processed paper 249/500: NOT_RELEVANT
# Processed paper 250/500: NOT_RELEVANT
# Processed paper 251/500: MAYBE_RELEVANT
# Processed paper 252/500: NOT_RELEVANT
# Processed paper 253/500: NOT_RELEVANT
# Processed paper 254/500: NOT_RELEVANT
# Processed paper 255/500: NOT_RELEVANT
# Processed paper 256/500: NOT_RELEVANT
# Processed paper 257/500: NOT_RELEVANT
# Processed paper 258/500: NOT_RELEVANT
# Processed paper 259/500: NOT_RELEVANT
# Processed paper 260/500: NOT_RELEVANT
# Processed paper 261/500: MAYBE_RELEVANT
# Processed paper 262/500: NOT_RELEVANT
# Processed paper 263/500: NOT_RELEVANT
# Processed paper 264/500: NOT_RELEVANT
# Processed paper 265/500: NOT_FOUND
# Processed paper 266/500: NOT_RELEVANT
# Processed paper 267/500: NOT_RELEVANT
# Processed paper 268/500: MAYBE_RELEVANT
# Processed paper 269/500: MAYBE_RELEVANT
# Processed paper 270/500: NOT_RELEVANT
# Processed paper 271/500: NOT_RELEVANT
# Processed paper 272/500: NOT_RELEVANT
# Processed paper 273/500: NOT_RELEVANT
# Processed paper 274/500: NOT_RELEVANT
# Processed paper 275/500: NOT_RELEVANT
# Processed paper 276/500: NOT_RELEVANT
# Processed paper 277/500: NOT_RELEVANT
# Processed paper 278/500: NOT_RELEVANT
# Processed paper 279/500: NOT_RELEVANT
# Processed paper 280/500: NOT_RELEVANT
# Processed paper 281/500: NOT_RELEVANT
# Processed paper 282/500: NOT_RELEVANT
# Processed paper 283/500: NOT_RELEVANT
# Processed paper 284/500: NOT_RELEVANT
# Processed paper 285/500: NOT_RELEVANT
# Processed paper 286/500: MAYBE_RELEVANT
# Processed paper 287/500: NOT_RELEVANT
# Processed paper 288/500: NOT_RELEVANT
# Processed paper 289/500: NOT_RELEVANT
# Processed paper 290/500: MAYBE_RELEVANT
# Processed paper 291/500: NOT_RELEVANT
# Processed paper 292/500: NOT_RELEVANT
# Processed paper 293/500: NOT_RELEVANT
# Processed paper 294/500: NOT_RELEVANT
# Processed paper 295/500: NOT_RELEVANT
# Processed paper 296/500: NOT_RELEVANT
# Processed paper 297/500: NOT_RELEVANT
# Processed paper 298/500: NOT_RELEVANT
# Processed paper 299/500: NOT_RELEVANT
# Processed paper 300/500: NOT_RELEVANT
# Processed paper 301/500: MAYBE_RELEVANT
# Processed paper 302/500: NOT_RELEVANT
# Processed paper 303/500: NOT_RELEVANT
# Processed paper 304/500: NOT_RELEVANT
# Processed paper 305/500: NOT_RELEVANT
# Processed paper 306/500: NOT_RELEVANT
# Processed paper 307/500: NOT_RELEVANT
# Processed paper 308/500: NOT_RELEVANT
# Processed paper 309/500: NOT_RELEVANT
# Processed paper 310/500: NOT_RELEVANT
# Processed paper 311/500: NOT_RELEVANT
# Processed paper 312/500: NOT_RELEVANT
# Processed paper 313/500: NOT_RELEVANT
# Processed paper 314/500: NOT_RELEVANT
# Processed paper 315/500: NOT_RELEVANT
# Processed paper 316/500: NOT_RELEVANT
# Processed paper 317/500: NOT_RELEVANT
# Processed paper 318/500: NOT_RELEVANT
# Processed paper 319/500: NOT_RELEVANT
# Processed paper 320/500: NOT_RELEVANT
# Processed paper 321/500: MAYBE_RELEVANT
# Processed paper 322/500: NOT_RELEVANT
# Processed paper 323/500: NOT_RELEVANT
# Processed paper 324/500: NOT_RELEVANT
# Processed paper 325/500: NOT_RELEVANT
# Processed paper 326/500: NOT_RELEVANT
# Processed paper 327/500: NOT_RELEVANT
# Processed paper 328/500: NOT_RELEVANT
# Processed paper 329/500: NOT_RELEVANT
# Processed paper 330/500: MAYBE_RELEVANT
# Processed paper 331/500: MAYBE_RELEVANT
# Processed paper 332/500: MAYBE_RELEVANT
# Processed paper 333/500: NOT_RELEVANT
# Processed paper 334/500: NOT_RELEVANT
# Processed paper 335/500: NOT_RELEVANT
# Processed paper 336/500: MAYBE_RELEVANT
# Processed paper 337/500: NOT_RELEVANT
# Processed paper 338/500: NOT_RELEVANT
# Processed paper 339/500: NOT_RELEVANT
# Processed paper 340/500: NOT_RELEVANT
# Processed paper 341/500: NOT_RELEVANT
# Processed paper 342/500: NOT_RELEVANT
# Processed paper 343/500: NOT_RELEVANT
# Processed paper 344/500: NOT_RELEVANT
# Processed paper 345/500: NOT_RELEVANT
# Processed paper 346/500: NOT_RELEVANT
# Processed paper 347/500: MAYBE_RELEVANT
# Processed paper 348/500: NOT_RELEVANT
# Processed paper 349/500: RELEVANT
# Processed paper 350/500: NOT_RELEVANT
# Processed paper 351/500: NOT_RELEVANT
# Processed paper 352/500: NOT_RELEVANT
# Processed paper 353/500: NOT_RELEVANT
# Processed paper 354/500: NOT_RELEVANT
# Processed paper 355/500: NOT_RELEVANT
# Processed paper 356/500: NOT_RELEVANT
# Processed paper 357/500: NOT_RELEVANT
# Processed paper 358/500: NOT_RELEVANT
# Processed paper 359/500: NOT_RELEVANT
# Processed paper 360/500: NOT_RELEVANT
# Processed paper 361/500: NOT_RELEVANT
# Processed paper 362/500: NOT_RELEVANT
# Processed paper 363/500: NOT_RELEVANT
# Processed paper 364/500: NOT_RELEVANT
# Processed paper 365/500: NOT_RELEVANT
# Processed paper 366/500: NOT_RELEVANT
# Processed paper 367/500: NOT_RELEVANT
# Processed paper 368/500: NOT_RELEVANT
# Processed paper 369/500: NOT_RELEVANT
# Processed paper 370/500: NOT_RELEVANT
# Processed paper 371/500: NOT_RELEVANT
# Processed paper 372/500: NOT_RELEVANT
# Processed paper 373/500: MAYBE_RELEVANT
# Processed paper 374/500: NOT_RELEVANT
# Processed paper 375/500: MAYBE_RELEVANT
# Processed paper 376/500: NOT_RELEVANT
# Processed paper 377/500: NOT_RELEVANT
# Processed paper 378/500: NOT_RELEVANT
# Processed paper 379/500: NOT_RELEVANT
# Processed paper 380/500: NOT_RELEVANT
# Processed paper 381/500: NOT_RELEVANT
# Processed paper 382/500: NOT_RELEVANT
# Processed paper 383/500: NOT_RELEVANT
# Processed paper 384/500: NOT_RELEVANT
# Processed paper 385/500: MAYBE_RELEVANT
# Processed paper 386/500: NOT_RELEVANT
# Processed paper 387/500: NOT_RELEVANT
# Processed paper 388/500: NOT_RELEVANT
# Processed paper 389/500: NOT_RELEVANT
# Processed paper 390/500: NOT_RELEVANT
# Processed paper 391/500: MAYBE_RELEVANT
# Processed paper 392/500: NOT_RELEVANT
# Processed paper 393/500: MAYBE_RELEVANT
# Processed paper 394/500: NOT_RELEVANT
# Processed paper 395/500: NOT_RELEVANT
# Processed paper 396/500: NOT_RELEVANT
# Processed paper 397/500: MAYBE_RELEVANT
# Processed paper 398/500: NOT_RELEVANT
# Processed paper 399/500: NOT_RELEVANT
# Processed paper 400/500: NOT_RELEVANT
# Processed paper 401/500: NOT_RELEVANT
# Processed paper 402/500: NOT_RELEVANT
# Processed paper 403/500: NOT_RELEVANT
# Processed paper 404/500: NOT_RELEVANT
# Processed paper 405/500: NOT_RELEVANT
# Processed paper 406/500: NOT_RELEVANT
# Processed paper 407/500: NOT_RELEVANT
# Processed paper 408/500: NOT_RELEVANT
# Processed paper 409/500: NOT_RELEVANT
# Processed paper 410/500: NOT_RELEVANT
# Processed paper 411/500: NOT_RELEVANT
# Processed paper 412/500: NOT_RELEVANT
# Processed paper 413/500: NOT_RELEVANT
# Processed paper 414/500: NOT_RELEVANT
# Processed paper 415/500: NOT_RELEVANT
# Processed paper 416/500: NOT_RELEVANT
# Processed paper 417/500: NOT_RELEVANT
# Processed paper 418/500: NOT_RELEVANT
# Processed paper 419/500: NOT_RELEVANT
# Processed paper 420/500: NOT_RELEVANT
# Processed paper 421/500: NOT_RELEVANT
# Processed paper 422/500: NOT_RELEVANT
# Processed paper 423/500: NOT_RELEVANT
# Processed paper 424/500: NOT_RELEVANT
# Processed paper 425/500: NOT_RELEVANT
# Processed paper 426/500: NOT_RELEVANT
# Processed paper 427/500: NOT_RELEVANT
# Processed paper 428/500: NOT_RELEVANT
# Processed paper 429/500: NOT_RELEVANT
# Processed paper 430/500: NOT_RELEVANT
# Processed paper 431/500: NOT_RELEVANT
# Processed paper 432/500: NOT_RELEVANT
# Processed paper 433/500: NOT_RELEVANT
# Processed paper 434/500: NOT_RELEVANT
# Processed paper 435/500: NOT_RELEVANT
# Processed paper 436/500: NOT_RELEVANT
# Processed paper 437/500: NOT_RELEVANT
# Processed paper 438/500: NOT_RELEVANT
# Processed paper 439/500: NOT_RELEVANT
# Processed paper 440/500: MAYBE_RELEVANT
# Processed paper 441/500: NOT_RELEVANT
# Processed paper 442/500: NOT_RELEVANT
# Processed paper 443/500: NOT_RELEVANT
# Processed paper 444/500: NOT_RELEVANT
# Processed paper 445/500: NOT_RELEVANT
# Processed paper 446/500: NOT_RELEVANT
# Processed paper 447/500: NOT_RELEVANT
# Processed paper 448/500: NOT_FOUND
# Processed paper 449/500: NOT_FOUND
# Processed paper 450/500: NOT_FOUND
# Processed paper 451/500: NOT_FOUND
# Processed paper 452/500: NOT_FOUND
# Processed paper 453/500: NOT_FOUND
# Processed paper 454/500: NOT_FOUND
# Processed paper 455/500: NOT_FOUND
# Processed paper 456/500: NOT_FOUND
# Processed paper 457/500: NOT_FOUND
# Processed paper 458/500: NOT_FOUND
# Processed paper 459/500: NOT_FOUND
# Processed paper 460/500: NOT_FOUND
# Processed paper 461/500: NOT_FOUND
# Processed paper 462/500: NOT_FOUND
# Processed paper 463/500: NOT_FOUND
# Processed paper 464/500: NOT_FOUND
# Processed paper 465/500: NOT_FOUND
# Processed paper 466/500: NOT_FOUND
# Processed paper 467/500: NOT_FOUND
# Processed paper 468/500: NOT_FOUND
# Processed paper 469/500: NOT_FOUND
# Processed paper 470/500: NOT_FOUND
# Processed paper 471/500: NOT_FOUND
# Processed paper 472/500: NOT_FOUND
# Processed paper 473/500: NOT_FOUND
# Processed paper 474/500: NOT_FOUND
# Processed paper 475/500: NOT_FOUND
# Processed paper 476/500: NOT_FOUND
# Processed paper 477/500: NOT_FOUND
# Processed paper 478/500: NOT_FOUND
# Processed paper 479/500: NOT_FOUND
# Processed paper 480/500: NOT_FOUND
# Processed paper 481/500: NOT_FOUND
# Processed paper 482/500: NOT_FOUND
# Processed paper 483/500: NOT_FOUND
# Processed paper 484/500: NOT_FOUND
# Processed paper 485/500: NOT_FOUND
# Processed paper 486/500: NOT_FOUND
# Processed paper 487/500: NOT_FOUND
# Processed paper 488/500: NOT_FOUND
# Processed paper 489/500: NOT_FOUND
# Processed paper 490/500: NOT_FOUND
#
# Processing complete. Results saved to processed_results_detailed.xlsx
