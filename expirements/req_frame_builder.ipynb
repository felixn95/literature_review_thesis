# %%
import os
from openai import OpenAI
import pandas as pd
import re
from dotenv import load_dotenv
import json

# 1) Load environment variables
load_dotenv()
OPENAI_MODEL = 'gpt-4o'  # as per your example

client = OpenAI(api_key=os.getenv('OPENAI_APIKEY'))


def call_openai_api(system_prompt, user_prompt):
    """
    Calls the OpenAI ChatCompletion endpoint and returns the full response object.
    This is a separate function so we can debug the raw response before JSON parsing.
    """
    try:
        response = client.chat.completions.create(
            model=OPENAI_MODEL,
            temperature=0.1,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
           # response_format={"type": "json_object"}  # optional if your endpoint supports this
        )
        return response
    except Exception as e:
        print(f"Error calling OpenAI API: {e}")
        return None


def extract_requirements_from_row(paper_name, row_text):
    """
    Sends a row’s text (with requirements) to the OpenAI ChatCompletion endpoint
    to extract structured data in JSON. 
    Returns a Python list of dictionaries with the columns:
      - Requirement
      - Found_Content_With_Page
      - Paper
    """
    system_prompt = (
        "You are a data-extraction assistant. You receive text describing requirements found in a paper. "
        "Your goal is to extract structured data in strict JSON format."
    )

    user_prompt = f"""
Extract **all** requirements from the text. 
- Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
- The text may contain multiple requirements; you must find **all** occurrences.
- For each requirement found, return an object with the following keys:
  1) "Requirement": the requirement code (e.g. "R4"),
  2) "Found_Content_With_Page": the text associated with that requirement (including page number),
  3) "Paper": the provided paper filename.

Each object should correspond to **one** requirement from the text.
Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.

**Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.

Here is an example with **multiple** requirements:

**Example of desired JSON output**:
[
  {{
    "Requirement": "R1",
    "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
    "Paper": "MyPaper.pdf"
  }},
  {{
    "Requirement": "R4",
    "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
    "Paper": "MyPaper.pdf"
  }},
  {{
    "Requirement": "R10",
    "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
    "Paper": "MyPaper.pdf"
  }}
]

PAPER NAME: {paper_name}
TEXT:
{row_text}
"""
    print ("User Prompt: ", user_prompt)
    # 1) Call the API
    response = call_openai_api(system_prompt, user_prompt)
    if response is None:
        print("No response from API, returning empty list.")
        return []

    # 2) Inspect the raw response for debugging
    print("--------------- RAW RESPONSE ---------------")
    print(response)
    print("--------------------------------------------")
    # Typically, the content is in `response.choices[0].message.content`
    json_string = response.choices[0].message.content
    # Remove code fences if present
    json_string_clean = re.sub(r"^```[a-zA-Z]*\n?", "", json_string.strip())
    json_string_clean = re.sub(r"```$", "", json_string_clean).strip()

    # 3) Attempt to extract the JSON from the response
    try:
        print("----- RAW CONTENT FROM THE MODEL -----")
        print(json_string_clean)
        print("--------------------------------------")

        # 4) Parse the JSON string
        extracted_data = json.loads(json_string_clean)

        # 5) If it's a dict, wrap in a list to normalize
        if isinstance(extracted_data, dict):
            extracted_data = [extracted_data]

        # 6) Confirm success
        print(f"Extracted {len(extracted_data)} requirements from '{paper_name}'")
        return extracted_data

    except json.JSONDecodeError as e:
        print("Error loading JSON: ", e)
        print("Raw response content was:\n", response.choices[0].message.content)
        return []
    except Exception as e:
        print(f"Unexpected error parsing JSON: {e}")
        return []


def process_excel(input_excel="req_matches.xlsx", output_excel="req_matches_parsed.xlsx", n_rows=3):
    """
    Main function to:
    1) Read an input Excel file
    2) Extract requirement data from each row
    3) Write results to a new Excel file
    """
    # 2) Read the original Excel file
    df_input = pd.read_excel(input_excel)

    # Suppose your DataFrame has columns ["Paper", "Requirements Match"]
    # Adjust as needed based on your actual column names
    all_extracted_rows = []

    # If you'd like to process all rows, remove .head(n_rows)
    for idx, row in df_input.head(n_rows).iterrows():
        paper_name = row["Paper"]  # adjust column name if different
        row_text = row["Requirements Match"]  # adjust column name if different

        # 3) Extract the requirements via OpenAI
        extracted_list = extract_requirements_from_row(paper_name, row_text)

        # 4) Append each extracted requirement to a master list
        for item in extracted_list:
            all_extracted_rows.append(item)

    # 5) Convert to DataFrame & save
    df_output = pd.DataFrame(
        all_extracted_rows,
        columns=["Requirement", "Found_Content_With_Page", "Paper"]
    )

    # 6) Write the result to a new Excel
    df_output.to_excel(output_excel, index=False)
    print(f"Results written to {output_excel}")

# %%
process_excel(
    input_excel="req_matches.xlsx",
    output_excel="req_matches_parsed_2.xlsx",
    n_rows=50  # or however many rows you want to process
)
# Out:
# User Prompt:
# Extract **all** requirements from the text.
# - Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.
#
# **Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.
#
# Here is an example with **multiple** requirements:
#
# **Example of desired JSON output**:
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
#     "Paper": "MyPaper.pdf"
#   }
# ]
#
# PAPER NAME: Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf
# TEXT:
# (R9)Traceability:  Traceability can also help validate that the right system is being built, effectively meeting user and business needs as specified in the use
# case. (p.2)
#
# (R12)Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language:
# The performance of an LLM with RAG depends
# on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)
#
# (R11) Data Variety:
# We handled the use of structured data (Code dependencies) and unstructured data (natural language requirements from documents).
#
# (R2) Performance Indicators / Measurability: Used a defined set of questions to validate the solution (p.11).
#
# (R1) Productivity & (R4) Costs: A traceable relationship between requirements, conceptual design, and implementation helps effective communication about the software across stakeholders. However, manually maintaining traceability is costly and error-prone [14] (p.2).
#
# --------------- RAW RESPONSE ---------------
# ChatCompletion(id='chatcmpl-AooVfjLZLpRT082JV49GnTM9UdUuZ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[\n  {\n    "Requirement": "R9",\n    "Found_Content_With_Page": "Traceability: Traceability can also help validate that the right system is being built, effectively meeting user and business needs as specified in the use case. (p.2)",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R12",\n    "Found_Content_With_Page": "Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language: The performance of an LLM with RAG depends on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R7",\n    "Found_Content_With_Page": "Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language: The performance of an LLM with RAG depends on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R6",\n    "Found_Content_With_Page": "Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language: The performance of an LLM with RAG depends on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R11",\n    "Found_Content_With_Page": "Data Variety: We handled the use of structured data (Code dependencies) and unstructured data (natural language requirements from documents).",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R2",\n    "Found_Content_With_Page": "Performance Indicators / Measurability: Used a defined set of questions to validate the solution (p.11).",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R1",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: A traceable relationship between requirements, conceptual design, and implementation helps effective communication about the software across stakeholders. However, manually maintaining traceability is costly and error-prone [14] (p.2).",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"\n  },\n  {\n    "Requirement": "R4",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: A traceable relationship between requirements, conceptual design, and implementation helps effective communication about the software across stakeholders. However, manually maintaining traceability is costly and error-prone [14] (p.2).",\n    "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requ ...
# --------------------------------------------
# ----- RAW CONTENT FROM THE MODEL -----
# [
#   {
#     "Requirement": "R9",
#     "Found_Content_With_Page": "Traceability: Traceability can also help validate that the right system is being built, effectively meeting user and business needs as specified in the use case. (p.2)",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R12",
#     "Found_Content_With_Page": "Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language: The performance of an LLM with RAG depends on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R7",
#     "Found_Content_With_Page": "Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language: The performance of an LLM with RAG depends on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R6",
#     "Found_Content_With_Page": "Data Quality and Actuality & (R7) Context Relevance & (R6) Natural Language: The performance of an LLM with RAG depends on the quality of the RAG index. The RAG index acts as a contextual bridge between the query and the response from an LLM. The better the context provided by a RAG index for given requirements in natural language as a query is, the better an LLM responds by disambiguating the requirements. (p.3)",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R11",
#     "Found_Content_With_Page": "Data Variety: We handled the use of structured data (Code dependencies) and unstructured data (natural language requirements from documents).",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R2",
#     "Found_Content_With_Page": "Performance Indicators / Measurability: Used a defined set of questions to validate the solution (p.11).",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: A traceable relationship between requirements, conceptual design, and implementation helps effective communication about the software across stakeholders. However, manually maintaining traceability is costly and error-prone [14] (p.2).",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: A traceable relationship between requirements, conceptual design, and implementation helps effective communication about the software across stakeholders. However, manually maintaining traceability is costly and error-prone [14] (p.2).",
#     "Paper": "Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf"
#   }
# ]
# --------------------------------------
# Extracted 8 requirements from 'Ali_2024_Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs.pdf'
# User Prompt:
# Extract **all** requirements from the text.
# - Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.
#
# **Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.
#
# Here is an example with **multiple** requirements:
#
# **Example of desired JSON output**:
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
#     "Paper": "MyPaper.pdf"
#   }
# ]
#
# PAPER NAME: Arslan_2024_Business insights using RAG LLMs a review and case study.pdf
# TEXT:
# (R11) Data Variety:  The paper discusses how organizations rely on diverse information sources and the need for efficient Information Extraction (IE) methods (p.1).  As these data, both structured and unstructured, grows in volume efficient Information Extraction (IE) methods become essential for informed decision-making. The case study describes the dataset used (2,845 news articles) and the types of information extracted, such as company names, financial figures, and industry trends.
# This complexity arises from the need to handle varying information structures and apply a range of IE tasks tailored to the specific needs of the organisation (p.21).
#
#  (R12)Data Quality and Actuality
# The requirement in the case study was to provide continuous access to the latest data, ensuring responses are current and relevant (p.22).
#
# (R1) Productivity & (R4) Costs:
# Manual processes also require costly and time-consuming verification to ensure information accuracy, further complicating and slowing down business operations (p.1).
# A news aggregation company aimed to extract valuable business opportunities from
# online articles for its clients.  Reading each news article and extracting key details is a time-consuming process that requires a significant number of company resources. (p.14)
#
# (R3) Organizational Acceptance: The case study outlines the specific requirements of the BI team, emphasizing the importance of understanding user needs and expectations to gain acceptance.
#
# (R2) Performance Indicators / Measurability: Used a defined set of questions to validate the solution.  These metrics are crucial for gauging the quality of information provided by the Chatbot, which hinges on both the relevance and completeness of the retrieved data (p.18).
#
# (R7) Context Relevance : LLMs exhibit potential for IE tasks but face challenges with domain-specific queries, often generating inaccurate or misleading information, known as ‘hallucinations’ (Kandpal et al., 2023). These hallucinations can
# arise from an overload of data, a lack of contextual relevance, or both, compromising the reliability of LLMs in practical applications (Y. Gao et al., 2023). (p.2).The requirement in the case study was to provide continuous access to the latest data, ensuring responses are current and relevant (p.22).
#
# (R5) User-Friendliness & Accessibility: mentions the challenges smaller organizations face due to a lack of expertise and resources, indicating a need for user-friendly solutions. (p.2)
#
# (R6) Natural Language
# To facilitate interactive exploration of business opportunities, we opted to design a Business
# Chatbot Assistant based on insights gathered from the existing literature. This choice
# allows seamless interaction with business users, enhancing their ability to explore information effectively. (p.15)
#
# (R10) Reasonable Response Times:  Increasing the size of the dataset can lead to longer retrieval
# times due to the greater volume of documents the LLM needs to process. Our study
# did not address how the retrieval time is affected by dataset size. Future research
# should examine the impact of larger datasets on response times and explore potential optimizations to manage this challenge. (p.23) -> highlights the need for reasonable response times.
#
# (R14) Adaptability & Scalability:
# The system’s design needs to allows for easy adaptation to
# various business applications and disciplines. Additionally, the system’s scalability accommodates increasing data volumes and evolving business needs, maintaining effectiveness and efficiency as requirements expand. (p.22)
#
# --------------- RAW RESPONSE ---------------
# ChatCompletion(id='chatcmpl-AooVplTQYiRKQ1jt4jnVHoQBNv2QU', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[\n  {\n    "Requirement": "R11",\n    "Found_Content_With_Page": "Data Variety:  The paper discusses how organizations rely on diverse information sources and the need for efficient Information Extraction (IE) methods (p.1).  As these data, both structured and unstructured, grows in volume efficient Information Extraction (IE) methods become essential for informed decision-making. The case study describes the dataset used (2,845 news articles) and the types of information extracted, such as company names, financial figures, and industry trends. This complexity arises from the need to handle varying information structures and apply a range of IE tasks tailored to the specific needs of the organisation (p.21).",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"\n  },\n  {\n    "Requirement": "R12",\n    "Found_Content_With_Page": "Data Quality and Actuality The requirement in the case study was to provide continuous access to the latest data, ensuring responses are current and relevant (p.22).",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"\n  },\n  {\n    "Requirement": "R1",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: Manual processes also require costly and time-consuming verification to ensure information accuracy, further complicating and slowing down business operations (p.1). A news aggregation company aimed to extract valuable business opportunities from online articles for its clients. Reading each news article and extracting key details is a time-consuming process that requires a significant number of company resources. (p.14)",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"\n  },\n  {\n    "Requirement": "R4",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: Manual processes also require costly and time-consuming verification to ensure information accuracy, further complicating and slowing down business operations (p.1). A news aggregation company aimed to extract valuable business opportunities from online articles for its clients. Reading each news article and extracting key details is a time-consuming process that requires a significant number of company resources. (p.14)",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"\n  },\n  {\n    "Requirement": "R3",\n    "Found_Content_With_Page": "Organizational Acceptance: The case study outlines the specific requirements of the BI team, emphasizing the importance of understanding user needs and expectations to gain acceptance.",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"\n  },\n  {\n    "Requirement": "R2",\n    "Found_Content_With_Page": "Performance Indicators / Measurability: Used a defined set of questions to validate the solution. These metrics are crucial for gauging the quality of information provided by the Chatbot, which hinges on both the relevance and completeness of the retrieved data (p.18).",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"\n  },\n  {\n    "Requirement": "R7",\n    "Found_Content_With_Page": "Context Relevance : LLMs exhibit potential for IE tasks but face challenges with domain-specific queries, often generating inaccurate or misleading information, known as ‘hallucinations’ (Kandpal et al., 2023). These hallucinations can arise from an overload of data, a lack of contextual relevance, or both, compromising the reliability of LLMs in practical applications (Y. Gao et al., 2023). (p.2).The requirement in the case study was to provide continuous access to the latest data, ensuring responses are current and relevant (p.22).",\n    "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pd ...
# --------------------------------------------
# ----- RAW CONTENT FROM THE MODEL -----
# [
#   {
#     "Requirement": "R11",
#     "Found_Content_With_Page": "Data Variety:  The paper discusses how organizations rely on diverse information sources and the need for efficient Information Extraction (IE) methods (p.1).  As these data, both structured and unstructured, grows in volume efficient Information Extraction (IE) methods become essential for informed decision-making. The case study describes the dataset used (2,845 news articles) and the types of information extracted, such as company names, financial figures, and industry trends. This complexity arises from the need to handle varying information structures and apply a range of IE tasks tailored to the specific needs of the organisation (p.21).",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R12",
#     "Found_Content_With_Page": "Data Quality and Actuality The requirement in the case study was to provide continuous access to the latest data, ensuring responses are current and relevant (p.22).",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: Manual processes also require costly and time-consuming verification to ensure information accuracy, further complicating and slowing down business operations (p.1). A news aggregation company aimed to extract valuable business opportunities from online articles for its clients. Reading each news article and extracting key details is a time-consuming process that requires a significant number of company resources. (p.14)",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: Manual processes also require costly and time-consuming verification to ensure information accuracy, further complicating and slowing down business operations (p.1). A news aggregation company aimed to extract valuable business opportunities from online articles for its clients. Reading each news article and extracting key details is a time-consuming process that requires a significant number of company resources. (p.14)",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R3",
#     "Found_Content_With_Page": "Organizational Acceptance: The case study outlines the specific requirements of the BI team, emphasizing the importance of understanding user needs and expectations to gain acceptance.",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R2",
#     "Found_Content_With_Page": "Performance Indicators / Measurability: Used a defined set of questions to validate the solution. These metrics are crucial for gauging the quality of information provided by the Chatbot, which hinges on both the relevance and completeness of the retrieved data (p.18).",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R7",
#     "Found_Content_With_Page": "Context Relevance : LLMs exhibit potential for IE tasks but face challenges with domain-specific queries, often generating inaccurate or misleading information, known as ‘hallucinations’ (Kandpal et al., 2023). These hallucinations can arise from an overload of data, a lack of contextual relevance, or both, compromising the reliability of LLMs in practical applications (Y. Gao et al., 2023). (p.2).The requirement in the case study was to provide continuous access to the latest data, ensuring responses are current and relevant (p.22).",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R5",
#     "Found_Content_With_Page": "User-Friendliness & Accessibility: mentions the challenges smaller organizations face due to a lack of expertise and resources, indicating a need for user-friendly solutions. (p.2)",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R6",
#     "Found_Content_With_Page": "Natural Language To facilitate interactive exploration of business opportunities, we opted to design a Business Chatbot Assistant based on insights gathered from the existing literature. This choice allows seamless interaction with business users, enhancing their ability to explore information effectively. (p.15)",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Reasonable Response Times:  Increasing the size of the dataset can lead to longer retrieval times due to the greater volume of documents the LLM needs to process. Our study did not address how the retrieval time is affected by dataset size. Future research should examine the impact of larger datasets on response times and explore potential optimizations to manage this challenge. (p.23) -> highlights the need for reasonable response times.",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   },
#   {
#     "Requirement": "R14",
#     "Found_Content_With_Page": "Adaptability & Scalability: The system’s design needs to allows for easy adaptation to various business applications and disciplines. Additionally, the system’s scalability accommodates increasing data volumes and evolving business needs, maintaining effectiveness and efficiency as requirements expand. (p.22)",
#     "Paper": "Arslan_2024_Business insights using RAG LLMs a review and case study.pdf"
#   }
# ]
# --------------------------------------
# Extracted 11 requirements from 'Arslan_2024_Business insights using RAG LLMs a review and case study.pdf'
# User Prompt:
# Extract **all** requirements from the text.
# - Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.
#
# **Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.
#
# Here is an example with **multiple** requirements:
#
# **Example of desired JSON output**:
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
#     "Paper": "MyPaper.pdf"
#   }
# ]
#
# PAPER NAME: Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf
# TEXT:
# (R11) Data Variety:  The paper discusses the need to extract information from different sources about the energy sector - this information spans various domains, including
# the latest government policies, funding, and support schemes. Currently, SMEs lack an integrated system that consolidates data from diverse media sources into a centralized Information System (IS), limiting their ability to effectively navigate SEIs." (p.1)
#
# (R12) Data Quality and Actuality:
#    - "Accessing timely information on SEIs including government policies, funding, technologies, and environmental impacts from various media sources is essential for guiding effective SETs and understanding the relevant Energy landscape.  Each SEI necessitates upto-date knowledge of government policies, funding, and support schemes." (p.1)
#
#
# (R1) Productivity & (R4) Costs:
# This gap is critical because a centralized IS is essential for helping SMEs drive SETs by providing all available and updated information about SEIs and the related Energy landscape. The absence of such a system often results in inefficiencies and increased costs, as existing systems fail to aggregate information effectively. (p.2)
#
# (R2) Performance Indicators / Measurability: Used a defined set of questions to validate the solution in the specific energy sector.  These metrics are crucial for gauging the quality of information provided by the Chatbot, which hinges on both the relevance and completeness of the retrieved data (p.4).
#
# (R7) Context Relevance : highlight to focus on the quality of information present in the Chatbot’s answers, which depends on the relevance and completeness of the information retrieved. (p.8)
#
# (R5) User-Friendliness & Accessibility & (R6) Natural Language: The choice of a QA Chatbot is supported by existing literature that highlights its benefits in enhancing user interaction and engagement with IS. Chatbots streamline the process of querying and retrieving information, providing quick responses and improving accessibility for users. Effective in complex domains where information needs to be synthesized and communicated in a userfriendly manner. (p.3f)
#
# (R10) Reasonable Response Times:  Increasing the size of the dataset can lead to longer retrieval
# times due to the greater volume of documents the LLM needs to process. Our study
# did not address how the retrieval time is affected by dataset size. Future research
# should examine the impact of larger datasets on response times and explore potential optimizations to manage this challenge. (p.14) -> highlights the need for reasonable response times.
#
# R14) Adaptability & Scalability:
#    - "The system is designed to be a sustainable solution by allowing for easy upgrades and customization." (p.2).  Updating the system involves simply replacing old data files with new ones, making the development and upgrade process efficient and requiring minimal time and resources. (p.14)
#
# (R16) Regulatory Compliance: "The Energy Chatbot provides SMEs with a centralized, efficient tool for accessing industry trends and technological advancements while supporting long-term sustainability goals and compliance with regulations." (p.2)
#
# (R18) Sustainability: The requirement was  to ensure sustainability, allowing it to remain both upgradable and customizable to adapt to the evolving needs and interests of organizations over time, since LLMs are known to have a markable environmental footprint. (p.2)
#
# --------------- RAW RESPONSE ---------------
# ChatCompletion(id='chatcmpl-AooW2lW9mXwDKx6vmTIkWZJdMfNsM', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[\n  {\n    "Requirement": "R11",\n    "Found_Content_With_Page": "Data Variety: The paper discusses the need to extract information from different sources about the energy sector - this information spans various domains, including the latest government policies, funding, and support schemes. Currently, SMEs lack an integrated system that consolidates data from diverse media sources into a centralized Information System (IS), limiting their ability to effectively navigate SEIs.\\" (p.1)",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R12",\n    "Found_Content_With_Page": "Data Quality and Actuality: - \\"Accessing timely information on SEIs including government policies, funding, technologies, and environmental impacts from various media sources is essential for guiding effective SETs and understanding the relevant Energy landscape. Each SEI necessitates up-to-date knowledge of government policies, funding, and support schemes.\\" (p.1)",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R1",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: This gap is critical because a centralized IS is essential for helping SMEs drive SETs by providing all available and updated information about SEIs and the related Energy landscape. The absence of such a system often results in inefficiencies and increased costs, as existing systems fail to aggregate information effectively. (p.2)",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R4",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: This gap is critical because a centralized IS is essential for helping SMEs drive SETs by providing all available and updated information about SEIs and the related Energy landscape. The absence of such a system often results in inefficiencies and increased costs, as existing systems fail to aggregate information effectively. (p.2)",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R2",\n    "Found_Content_With_Page": "Performance Indicators / Measurability: Used a defined set of questions to validate the solution in the specific energy sector. These metrics are crucial for gauging the quality of information provided by the Chatbot, which hinges on both the relevance and completeness of the retrieved data (p.4).",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R7",\n    "Found_Content_With_Page": "Context Relevance : highlight to focus on the quality of information present in the Chatbot’s answers, which depends on the relevance and completeness of the information retrieved. (p.8)",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R5",\n    "Found_Content_With_Page": "User-Friendliness & Accessibility & (R6) Natural Language: The choice of a QA Chatbot is supported by existing literature that highlights its benefits in enhancing user interaction and engagement with IS. Chatbots streamline the process of querying and retrieving information, providing quick responses and improving accessibility for users. Effective in complex domains where information needs to be synthesized and communicated in a user-friendly manner. (p.3f)",\n    "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"\n  },\n  {\n    "Requirement": "R6",\n    "Found_Content_With_Page": "User-Friendliness & Accessibility & (R6) Natural Languag ...
# --------------------------------------------
# ----- RAW CONTENT FROM THE MODEL -----
# [
#   {
#     "Requirement": "R11",
#     "Found_Content_With_Page": "Data Variety: The paper discusses the need to extract information from different sources about the energy sector - this information spans various domains, including the latest government policies, funding, and support schemes. Currently, SMEs lack an integrated system that consolidates data from diverse media sources into a centralized Information System (IS), limiting their ability to effectively navigate SEIs.\" (p.1)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R12",
#     "Found_Content_With_Page": "Data Quality and Actuality: - \"Accessing timely information on SEIs including government policies, funding, technologies, and environmental impacts from various media sources is essential for guiding effective SETs and understanding the relevant Energy landscape. Each SEI necessitates up-to-date knowledge of government policies, funding, and support schemes.\" (p.1)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: This gap is critical because a centralized IS is essential for helping SMEs drive SETs by providing all available and updated information about SEIs and the related Energy landscape. The absence of such a system often results in inefficiencies and increased costs, as existing systems fail to aggregate information effectively. (p.2)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: This gap is critical because a centralized IS is essential for helping SMEs drive SETs by providing all available and updated information about SEIs and the related Energy landscape. The absence of such a system often results in inefficiencies and increased costs, as existing systems fail to aggregate information effectively. (p.2)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R2",
#     "Found_Content_With_Page": "Performance Indicators / Measurability: Used a defined set of questions to validate the solution in the specific energy sector. These metrics are crucial for gauging the quality of information provided by the Chatbot, which hinges on both the relevance and completeness of the retrieved data (p.4).",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R7",
#     "Found_Content_With_Page": "Context Relevance : highlight to focus on the quality of information present in the Chatbot’s answers, which depends on the relevance and completeness of the information retrieved. (p.8)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R5",
#     "Found_Content_With_Page": "User-Friendliness & Accessibility & (R6) Natural Language: The choice of a QA Chatbot is supported by existing literature that highlights its benefits in enhancing user interaction and engagement with IS. Chatbots streamline the process of querying and retrieving information, providing quick responses and improving accessibility for users. Effective in complex domains where information needs to be synthesized and communicated in a user-friendly manner. (p.3f)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R6",
#     "Found_Content_With_Page": "User-Friendliness & Accessibility & (R6) Natural Language: The choice of a QA Chatbot is supported by existing literature that highlights its benefits in enhancing user interaction and engagement with IS. Chatbots streamline the process of querying and retrieving information, providing quick responses and improving accessibility for users. Effective in complex domains where information needs to be synthesized and communicated in a user-friendly manner. (p.3f)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Reasonable Response Times: Increasing the size of the dataset can lead to longer retrieval times due to the greater volume of documents the LLM needs to process. Our study did not address how the retrieval time is affected by dataset size. Future research should examine the impact of larger datasets on response times and explore potential optimizations to manage this challenge. (p.14) -> highlights the need for reasonable response times.",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R14",
#     "Found_Content_With_Page": "Adaptability & Scalability: - \"The system is designed to be a sustainable solution by allowing for easy upgrades and customization.\" (p.2). Updating the system involves simply replacing old data files with new ones, making the development and upgrade process efficient and requiring minimal time and resources. (p.14)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R16",
#     "Found_Content_With_Page": "Regulatory Compliance: \"The Energy Chatbot provides SMEs with a centralized, efficient tool for accessing industry trends and technological advancements while supporting long-term sustainability goals and compliance with regulations.\" (p.2)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   },
#   {
#     "Requirement": "R18",
#     "Found_Content_With_Page": "Sustainability: The requirement was to ensure sustainability, allowing it to remain both upgradable and customizable to adapt to the evolving needs and interests of organizations over time, since LLMs are known to have a markable environmental footprint. (p.2)",
#     "Paper": "Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf"
#   }
# ]
# --------------------------------------
# Extracted 12 requirements from 'Arslan_2024_Driving sustainable energy transitions with a multi-source RAG-LLM system.pdf'
# User Prompt:
# Extract **all** requirements from the text.
# - Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.
#
# **Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.
#
# Here is an example with **multiple** requirements:
#
# **Example of desired JSON output**:
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
#     "Paper": "MyPaper.pdf"
#   }
# ]
#
# PAPER NAME: Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf
# TEXT:
# (R1) Productivity & (R4) Costs:
# Paper outlines a case study of searching through regulatory documents in the insurance sector. Effective retrieval can streamline the compliance process and reduce the
# time required for compliance assessment. (p.25)
#
# R16)  Regulatory Compliance:
# Paper outlines a case study of searching through regulatory documents in the insurance sector. Using AI-technologies like LLMs "Insurers have a responsibility to comply with regulatory requirements." (p.4)
#
# (R17) Fairness & Bias:
# Paper outlines a case study of searching through regulatory documents in the insurance sector. "LLMs are subject to the same biases and misinformation that humans who produce and consume internet content are exposed to." (p.31)
#
# --------------- RAW RESPONSE ---------------
# ChatCompletion(id='chatcmpl-AooWEVfCprFwocEY9wXdqd43Pp3uI', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[\n  {\n    "Requirement": "R1",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: Paper outlines a case study of searching through regulatory documents in the insurance sector. Effective retrieval can streamline the compliance process and reduce the time required for compliance assessment. (p.25)",\n    "Paper": "Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf"\n  },\n  {\n    "Requirement": "R4",\n    "Found_Content_With_Page": "Productivity & (R4) Costs: Paper outlines a case study of searching through regulatory documents in the insurance sector. Effective retrieval can streamline the compliance process and reduce the time required for compliance assessment. (p.25)",\n    "Paper": "Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf"\n  },\n  {\n    "Requirement": "R17",\n    "Found_Content_With_Page": "Fairness & Bias: Paper outlines a case study of searching through regulatory documents in the insurance sector. \\"LLMs are subject to the same biases and misinformation that humans who produce and consume internet content are exposed to.\\" (p.31)",\n    "Paper": "Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf"\n  }\n]', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736673958, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_b7d65f1a5b', usage=CompletionUsage(completion_tokens=285, prompt_tokens=575, total_tokens=860, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# --------------------------------------------
# ----- RAW CONTENT FROM THE MODEL -----
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: Paper outlines a case study of searching through regulatory documents in the insurance sector. Effective retrieval can streamline the compliance process and reduce the time required for compliance assessment. (p.25)",
#     "Paper": "Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Productivity & (R4) Costs: Paper outlines a case study of searching through regulatory documents in the insurance sector. Effective retrieval can streamline the compliance process and reduce the time required for compliance assessment. (p.25)",
#     "Paper": "Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf"
#   },
#   {
#     "Requirement": "R17",
#     "Found_Content_With_Page": "Fairness & Bias: Paper outlines a case study of searching through regulatory documents in the insurance sector. \"LLMs are subject to the same biases and misinformation that humans who produce and consume internet content are exposed to.\" (p.31)",
#     "Paper": "Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf"
#   }
# ]
# --------------------------------------
# Extracted 3 requirements from 'Balona_2023_ActuaryGPT_ApplicationsOfLLMs_ToInsuranceAndActuarialWork.pdf'
# User Prompt:
# Extract **all** requirements from the text.
# - Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# ...
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.
#
# **Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.
#
# Here is an example with **multiple** requirements:
#
# **Example of desired JSON output**:
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
#     "Paper": "MyPaper.pdf"
#   }
# ]
#
# PAPER NAME: Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf
# TEXT:
# (R2) Performance Indicators / Measurability / Validation Metrics:
# The paper highlights the need for robust metrics to evaluate the performance of Retrieval-Augmented Generation (RAG) systems, particularly at the component level, emphasizing the complexity of developing metrics that accurately assess the quality of data retrieval and response generation. (p. 6)
#
# (R9) Traceability & Transparency:
# The paper mentions the need for enhancing the transparency of LLMs and reducing their uncertainty to increase trust and reliability in their outputs, which relates to traceability and transparency in the information retrieval process. (p. 6)
#
# (R11) Data Integration / Handling Data Variety:
# The paper highlights the challenges of processing and integrating various forms of external data, including unstructured and multi-modal content, indicating the need for effective data integration capabilities.
#
# (R12) Data Quality and Actuality:
# The retrieval of relevant data segments from a large, unstructured dataset can be computationally intensive and prone to errors. The challenge lies in developing efficient and accurate retrieval mechanisms.
#  (p. 6)
#
# (R14) Adaptability & Scalability:
# The paper mentions the need for applications to adapt to evolving demands and the importance of continuous adaptations to meet user needs, indicating a focus on scalability. (p. 6)
#
# --------------- RAW RESPONSE ---------------
# ChatCompletion(id='chatcmpl-Aooa6o1Ps3HSue2Doj21AFmTyd2mW', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[\n  {\n    "Requirement": "R2",\n    "Found_Content_With_Page": "The paper highlights the need for robust metrics to evaluate the performance of Retrieval-Augmented Generation (RAG) systems, particularly at the component level, emphasizing the complexity of developing metrics that accurately assess the quality of data retrieval and response generation. (p. 6)",\n    "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"\n  },\n  {\n    "Requirement": "R9",\n    "Found_Content_With_Page": "The paper mentions the need for enhancing the transparency of LLMs and reducing their uncertainty to increase trust and reliability in their outputs, which relates to traceability and transparency in the information retrieval process. (p. 6)",\n    "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"\n  },\n  {\n    "Requirement": "R11",\n    "Found_Content_With_Page": "The paper highlights the challenges of processing and integrating various forms of external data, including unstructured and multi-modal content, indicating the need for effective data integration capabilities.",\n    "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"\n  },\n  {\n    "Requirement": "R12",\n    "Found_Content_With_Page": "The retrieval of relevant data segments from a large, unstructured dataset can be computationally intensive and prone to errors. The challenge lies in developing efficient and accurate retrieval mechanisms. (p. 6)",\n    "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"\n  },\n  {\n    "Requirement": "R14",\n    "Found_Content_With_Page": "The paper mentions the need for applications to adapt to evolving demands and the importance of continuous adaptations to meet user needs, indicating a focus on scalability. (p. 6)",\n    "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"\n  }\n]', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736674198, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_b7d65f1a5b', usage=CompletionUsage(completion_tokens=468, prompt_tokens=694, total_tokens=1162, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# --------------------------------------------
# ----- RAW CONTENT FROM THE MODEL -----
# [
#   {
#     "Requirement": "R2",
#     "Found_Content_With_Page": "The paper highlights the need for robust metrics to evaluate the performance of Retrieval-Augmented Generation (RAG) systems, particularly at the component level, emphasizing the complexity of developing metrics that accurately assess the quality of data retrieval and response generation. (p. 6)",
#     "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"
#   },
#   {
#     "Requirement": "R9",
#     "Found_Content_With_Page": "The paper mentions the need for enhancing the transparency of LLMs and reducing their uncertainty to increase trust and reliability in their outputs, which relates to traceability and transparency in the information retrieval process. (p. 6)",
#     "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"
#   },
#   {
#     "Requirement": "R11",
#     "Found_Content_With_Page": "The paper highlights the challenges of processing and integrating various forms of external data, including unstructured and multi-modal content, indicating the need for effective data integration capabilities.",
#     "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"
#   },
#   {
#     "Requirement": "R12",
#     "Found_Content_With_Page": "The retrieval of relevant data segments from a large, unstructured dataset can be computationally intensive and prone to errors. The challenge lies in developing efficient and accurate retrieval mechanisms. (p. 6)",
#     "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"
#   },
#   {
#     "Requirement": "R14",
#     "Found_Content_With_Page": "The paper mentions the need for applications to adapt to evolving demands and the importance of continuous adaptations to meet user needs, indicating a focus on scalability. (p. 6)",
#     "Paper": "Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf"
#   }
# ]
# --------------------------------------
# Extracted 5 requirements from 'Zhao_2024_RetrievalAugmentedGenerationAndBeyond_HowToMakeLLMsUseExternalDataMoreWisely.pdf'
# User Prompt:
# Extract **all** requirements from the text.
# - Each requirement is marked with the pattern (R<Number>), for example (R4), (R12), etc.
# - The text may contain multiple requirements; you must find **all** occurrences.
# - For each requirement found, return an object with the following keys:
#   1) "Requirement": the requirement code (e.g. "R4"),
#   2) "Found_Content_With_Page": the text associated with that requirement (including page number),
#   3) "Paper": the provided paper filename.
#
# Each object should correspond to **one** requirement from the text.
# Return these objects in a JSON array. That means if you find 5 requirements, return an array of length 5. Output only valid JSON, with no extra text or code fences.
#
# **Important**: Do not stop after finding the first requirement. Keep scanning the text until you have processed every instance of the pattern (R\d+). If no requirements are found, return an empty array `[]`.
#
# Here is an example with **multiple** requirements:
#
# **Example of desired JSON output**:
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "Discusses productivity improvements (p. 1).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R4",
#     "Found_Content_With_Page": "Mentions cost considerations (p. 2).",
#     "Paper": "MyPaper.pdf"
#   },
#   {
#     "Requirement": "R10",
#     "Found_Content_With_Page": "Highlights organizational acceptance (p. 6).",
#     "Paper": "MyPaper.pdf"
#   }
# ]
#
# PAPER NAME: zhao_2024_chat2data_demo_vldb2024.pdf
# TEXT:
# (R1) Increased Productivity & Efficiency:
# The paper discusses how traditional data analysis methods create barriers for ordinary users who cannot write programming code or SQL queries. By utilizing large language models (LLMs) to enable natural language interactions, the proposed Chat2Data system aims to reduce these barriers and improve efficiency in data management tasks, thereby increasing productivity for users (p. 1).
#
# (R2) Performance Indicators / Measurability / Validation Metrics:
# The paper mentions the need for evaluating the quality of generated results with user feedback, indicating a mechanism for measuring the performance of the Chat2Data system (p. 3).
#
# (R5) User-Friendliness & Accessibility & (R6) Natural Language Use:
# Chat2Data approach in the paper is designed to allow users to interact with data using natural language, which makes it accessible to users with varying skill levels, including those who cannot write code (p. 1).
#
# (R11) Data Integration / Handling Data Variety:
# Chat2Data supports both structured and unstructured data, indicating its capability to handle data variety and integrate different data sources seamlessly (p. 2).
#
# (R13) Integration Capability / Modularity:
# The system is designed to utilize various APIs and tools for data analysis and visualization, showcasing its modularity and integration capability with existing data management systems (p. 2).
#
# --------------- RAW RESPONSE ---------------
# ChatCompletion(id='chatcmpl-AooaBAJGaSASNDRhAmaN7UqwEsWit', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[\n  {\n    "Requirement": "R1",\n    "Found_Content_With_Page": "The paper discusses how traditional data analysis methods create barriers for ordinary users who cannot write programming code or SQL queries. By utilizing large language models (LLMs) to enable natural language interactions, the proposed Chat2Data system aims to reduce these barriers and improve efficiency in data management tasks, thereby increasing productivity for users (p. 1).",\n    "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"\n  },\n  {\n    "Requirement": "R2",\n    "Found_Content_With_Page": "The paper mentions the need for evaluating the quality of generated results with user feedback, indicating a mechanism for measuring the performance of the Chat2Data system (p. 3).",\n    "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"\n  },\n  {\n    "Requirement": "R5",\n    "Found_Content_With_Page": "Chat2Data approach in the paper is designed to allow users to interact with data using natural language, which makes it accessible to users with varying skill levels, including those who cannot write code (p. 1).",\n    "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"\n  },\n  {\n    "Requirement": "R6",\n    "Found_Content_With_Page": "Chat2Data approach in the paper is designed to allow users to interact with data using natural language, which makes it accessible to users with varying skill levels, including those who cannot write code (p. 1).",\n    "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"\n  },\n  {\n    "Requirement": "R11",\n    "Found_Content_With_Page": "Chat2Data supports both structured and unstructured data, indicating its capability to handle data variety and integrate different data sources seamlessly (p. 2).",\n    "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"\n  },\n  {\n    "Requirement": "R13",\n    "Found_Content_With_Page": "The system is designed to utilize various APIs and tools for data analysis and visualization, showcasing its modularity and integration capability with existing data management systems (p. 2).",\n    "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"\n  }\n]', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736674203, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_b7d65f1a5b', usage=CompletionUsage(completion_tokens=501, prompt_tokens=695, total_tokens=1196, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# --------------------------------------------
# ----- RAW CONTENT FROM THE MODEL -----
# [
#   {
#     "Requirement": "R1",
#     "Found_Content_With_Page": "The paper discusses how traditional data analysis methods create barriers for ordinary users who cannot write programming code or SQL queries. By utilizing large language models (LLMs) to enable natural language interactions, the proposed Chat2Data system aims to reduce these barriers and improve efficiency in data management tasks, thereby increasing productivity for users (p. 1).",
#     "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"
#   },
#   {
#     "Requirement": "R2",
#     "Found_Content_With_Page": "The paper mentions the need for evaluating the quality of generated results with user feedback, indicating a mechanism for measuring the performance of the Chat2Data system (p. 3).",
#     "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"
#   },
#   {
#     "Requirement": "R5",
#     "Found_Content_With_Page": "Chat2Data approach in the paper is designed to allow users to interact with data using natural language, which makes it accessible to users with varying skill levels, including those who cannot write code (p. 1).",
#     "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"
#   },
#   {
#     "Requirement": "R6",
#     "Found_Content_With_Page": "Chat2Data approach in the paper is designed to allow users to interact with data using natural language, which makes it accessible to users with varying skill levels, including those who cannot write code (p. 1).",
#     "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"
#   },
#   {
#     "Requirement": "R11",
#     "Found_Content_With_Page": "Chat2Data supports both structured and unstructured data, indicating its capability to handle data variety and integrate different data sources seamlessly (p. 2).",
#     "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"
#   },
#   {
#     "Requirement": "R13",
#     "Found_Content_With_Page": "The system is designed to utilize various APIs and tools for data analysis and visualization, showcasing its modularity and integration capability with existing data management systems (p. 2).",
#     "Paper": "zhao_2024_chat2data_demo_vldb2024.pdf"
#   }
# ]
# --------------------------------------
# Extracted 6 requirements from 'zhao_2024_chat2data_demo_vldb2024.pdf'
# Results written to req_matches_parsed.xlsx
