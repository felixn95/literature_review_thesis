# %%
# read in the entire pdf and extract the text

import pandas as pd
from openai import OpenAI
import os
import json
from dotenv import load_dotenv
import pdfplumber

# Constants
INPUT_FILE = "G:\My Drive\Master IS\MasterThesis\Literature\Maybe_Relevant\Abdullahi2024_Retrieval-Based Diagnostic Decision SupportMixed Methods Study.pdf"
OPENAI_MODEL = 'gpt-4o-mini'
load_dotenv()
# Instantiate the OpenAI client
client = OpenAI(api_key=os.getenv('OPENAI_APIKEY'))  # You can omit the api_key if it's set in your environment


# read in text from pdf file
def read_pdf(file_path):
    with pdfplumber.open(file_path) as pdf:
        text = ''
        for page in pdf.pages:
            text += page.extract_text()
    return text


pdf_text = read_pdf(INPUT_FILE)

# %%
# print the text
print(pdf_text)
# Out:
# JMIR MEDICAL INFORMATICS Abdullahi et al
# Original Paper
# Retrieval-Based Diagnostic Decision Support: Mixed Methods
# Study
# Tassallah Abdullahi1, MSc; Laura Mercurio2, MD; Ritambhara Singh1,3, PhD; Carsten Eickhoff4, PhD
# 1Department of Computer Science, Brown University, Providence, RI, United States
# 2Departments of Pediatrics & Emergency Medicine, Alpert Medical School, Brown University, Providence, RI, United States
# 3Center for Computational Molecular Biology, Brown University, Providence, RI, United States
# 4School of Medicine, University of Tübingen, Tübingen, Germany
# Corresponding Author:
# Carsten Eickhoff, PhD
# School of Medicine
# University of Tübingen
# Schaffhausenstr, 77
# Tübingen, 72072
# Germany
# Phone: 49 7071 29 843
# Email: carsten.eickhoff@uni-tuebingen.de
# Abstract
# Background: Diagnostic errors pose significant health risks and contribute to patient mortality. With the growing accessibility
# of electronic health records, machine learning models offer a promising avenue for enhancing diagnosis quality. Current research
# has primarily focused on a limited set of diseases with ample training data, neglecting diagnostic scenarios with limited data
# availability.
# Objective: This study aims to develop an information retrieval (IR)–based framework that accommodates data sparsity to
# facilitate broader diagnostic decision support.
# Methods: We introduced an IR-based diagnostic decision support framework called CliniqIR. It uses clinical text records, the
# Unified Medical Language System Metathesaurus, and 33 million PubMed abstracts to classify a broad spectrum of diagnoses
# independent of training data availability. CliniqIR is designed to be compatible with any IR framework. Therefore, we implemented
# it using both dense and sparse retrieval approaches. We compared CliniqIR’s performance to that of pretrained clinical transformer
# models such as Clinical Bidirectional Encoder Representations from Transformers (ClinicalBERT) in supervised and zero-shot
# settings. Subsequently, we combined the strength of supervised fine-tuned ClinicalBERT and CliniqIR to build an ensemble
# framework that delivers state-of-the-art diagnostic predictions.
# Results: On a complex diagnosis data set (DC3) without any training data, CliniqIR models returned the correct diagnosis within
# their top 3 predictions. On the Medical Information Mart for Intensive Care III data set, CliniqIR models surpassed ClinicalBERT
# in predicting diagnoses with <5 training samples by an average difference in mean reciprocal rank of 0.10. In a zero-shot setting
# where models received no disease-specific training, CliniqIR still outperformed the pretrained transformer models with a greater
# mean reciprocal rank of at least 0.10. Furthermore, in most conditions, our ensemble framework surpassed the performance of
# its individual components, demonstrating its enhanced ability to make precise diagnostic predictions.
# Conclusions: Our experiments highlight the importance of IR in leveraging unstructured knowledge resources to identify
# infrequently encountered diagnoses. In addition, our ensemble framework benefits from combining the complementary strengths
# of the supervised and retrieval-based models to diagnose a broad spectrum of diseases.
# (JMIR Med Inform 2024;12:e50209) doi: 10.2196/50209
# KEYWORDS
# clinical decision support; rare diseases; ensemble learning; retrieval-augmented learning; machine learning; electronic health
# records; natural language processing; retrieval augmented generation; RAG; electronic health record; EHR; data sparsity;
# information retrieval
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 1
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# enhance model performance. However, the effectiveness of this
# Introduction
# approach still relies on the size of the data set available for
# fine-tuning. Zero-shot learning and few-shot learning [17,18]
# Background
# represent promising alternatives for fine-tuning large models
# Identifying an accurate and timely cause for a patient’s health
# with limited labeled data. In zero-shot learning, the model can
# problem represents a challenging and complex cognitive task.
# classify samples from classes without labeled training data.
# A clinician must consider a complex range of composite
# Few-shot learning requires at least one labeled example per
# information sources, including the patient’s medical history,
# class to enable the model to make accurate predictions. Although
# current state, imaging, laboratory test results, and other clinical
# some studies [19,20] have shown that pretrained language
# observations, to formulate an accurate diagnosis. Diagnostic
# models have zero-shot and few-shot learning capabilities, their
# errors are a leading cause of delayed treatment, potentially
# performance remains inferior to that of models trained on
# affecting millions of patients each year. Research suggests that
# extensive labeled data. While zero-shot and few-shot approaches
# these errors contribute to 6% to 17% of adverse events [1].
# have demonstrated success in the vision domain [21,22], their
# Studies [2,3] have shown that, rather than relying on a single application to language models remains an ongoing area of
# physician for a final diagnosis, obtaining recommendations research.
# from multiple physicians increases diagnostic accuracy. To
# Leveraging external knowledge resources can improve
# improve the diagnostic process while maintaining economic
# predictive performance, especially with a limited training sample
# feasibility, different variants of automated assistants, also known
# size, as shown in previous work by Prakash et al [7] and Müller
# as diagnostic decision support systems (DDSSs) and symptom
# et al [6]. Classical information retrieval (IR) systems can use a
# checkers, have been introduced [4]. Early DDSSs [1,5] were
# vast collection of resources for various applications with low
# driven by structured databases that maintain information about
# computational complexity and no need for labeled data. In the
# diseases and other medical information in a structured form.
# medical setting, studies [23-25] and competitions such as the
# Although promising, these systems have yet to be highly
# text retrieval conference (TREC) clinical decision support track
# successful for several reasons, including limited accessibility,
# [26] have focused on developing and evaluating IR systems to
# poor flexibility, and scalability issues [6,7]. Hence, the
# support clinician decision-making. Typically, these IR systems
# traditional DDSS is gradually being replaced by machine
# have been applied to biomedical literature retrieval to aid in
# learning and deep learning models.
# clinical decision support. However, these systems can also be
# Recent studies [8-13] highlight the importance of electronic adapted for other downstream clinical tasks. For example, Naik
# health records for supervised machine learning algorithms in et al [27] trained a model to predict patient admission outcomes
# health care. These algorithms use the electronic health record (ventilation need, mortality, and length of stay) by integrating
# of a patient as input to predict their diagnosis. However, relevant medical literature with patient notes, leaving an open
# supervised model development has been limited to a select question of how IR systems would fare in directly predicting
# number of diseases with higher prevalence and extensive the underlying diagnosis. Therefore, our study applied IR
# documentation due to the availability of large amounts of labeled techniques to perform literature-guided diagnostic prediction.
# data. As a result, infrequently occurring diagnoses remain poorly
# Objectives
# studied. In real-world diagnostic scenarios, physicians are faced
# We introduce “CliniqIR,” a novel clinical decision support
# with the challenge of identifying the correct diagnosis from a
# algorithm that uses an IR system to match a patient’s medical
# plethora of possibilities. Therefore, a system that considers a
# record to a specific diagnosis from a large pool of possible
# broad range of diagnoses, including rare conditions, is desirable
# diagnoses. Our study aimed to improve the current state of
# for improved diagnostic accuracy. However, recent studies
# predictive modeling and diagnostic decision support for a broad
# [14,15] demonstrate that traditional supervised learning models
# range of diagnoses regardless of their training data availability.
# are challenging to use in such scenarios due to their reliance on
# By using clinical text records and external knowledge sources,
# large, labeled data sets with many examples per diagnosis.
# including the Unified Medical Language System (UMLS)
# However, most clinical cohorts exhibit imbalanced class
# Metathesaurus [28] and PubMed abstracts [29], we demonstrated
# distributions, characterized by a long-tailed pattern [15,16] in
# that “CliniqIR” successfully generalizes to less common
# which certain diagnostic classes represent most training samples
# diagnostic categories with heavily skewed data distributions.
# whereas others exhibit few or even 0 data points. In such
# Our work also shows CliniqIR to be highly adaptable, allowing
# scenarios, most traditional supervised models overfit the
# for easy integration with any IR system. This flexibility ensures
# majority class, resulting in poor performance for the minority
# the model’s ability to adapt to available resources and work
# classes. As such, large labeled data sets may not be a
# across various retrieval methods.
# straightforward solution for achieving an efficient supervised
# classifier that supports diverse diagnoses. To assess CliniqIR’s ability to predict diagnoses with no
# available training samples, we evaluated its performance on the
# In response, researchers have leveraged a technique called
# DC3 data set [30]. We compared its performance to that of
# transfer learning, which is a widely used method for building
# pretrained clinical models in a zero-shot setting, and our results
# classifiers that enables generalization to classes with limited
# showed that CliniqIR has the capability to recognize a broad
# labeled data. A common transfer learning technique involves
# spectrum of rare and complex diseases without relying on
# fine-tuning pretrained models—models trained on large and
# labeled training data. We also compared the performance of
# diverse data sets—on a smaller, domain-specific corpus to
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 2
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# CliniqIR with that of supervised fine-tuned pretrained Our study highlights the valuable synergy between
# biomedical large language models and found that supervised retrieval-based systems and supervised learning models,
# models have limitations when used on highly imbalanced data, showcasing how their combination can achieve state-of-the-art
# especially for diagnoses with limited training samples. Then, performance, particularly in data sets characterized by a
# we leveraged an ensemble strategy combining CliniqIR and a long-tailed distribution. This finding holds significant promise
# fine-tuned Clinical Bidirectional Encoder Representations from and offers new avenues to address the challenges of imbalanced
# Transformers (ClinicalBERT) to make predictions for a wide data in various domains.
# range of diagnoses that include frequent and infrequent
# conditions, summarized in Figure 1.
# Figure 1. CliniqIR and Clinical Bidirectional Encoder Representations from Transformers (ClinicalBERT), classify patient notes and generate ranked
# lists of potential diagnoses. The reciprocal rank fusion (RRF) ensemble reranks the lists from both models to provide clinicians with a more accurate
# final ranking of differential diagnoses to aid the diagnostic process. MIMIC-III: Medical Information Mart for Intensive Care III; PMID: PubMed ID.
# medical history or summary was preprocessed and treated as a
# Methods
# query. To make inferences given a patient’s clinical note, as a
# preprocessing step, we first used QuickUMLS (Soldani and
# CliniqIR: The Retrieval-Based Model
# Goharian [31]) explained in the Knowledge Extraction Using
# Overview QuickUMLSsection, to extract medical keywords from the note
# to obtain a query. Next, we fed the query (preprocessed note)
# We present CliniqIR, a novel literature-guided system that maps
# to the retrieval system, which returned a list of matching relevant
# a patient’s note to a specific diagnosis. By leveraging unlabeled
# PubMed abstracts alongside the medical conditions mentioned
# external knowledge sources, CliniqIR uses an IR system to
# in each abstract. Afterward, we selected the top 100 items from
# classify a wide range of diagnoses without relying on the
# the list and then computed the frequency of each concept across
# availability of notes for each individual diagnosis (labeled
# the list of abstracts. Finally, the model returned a list of concepts
# training data). As a result, CliniqIR represents a valuable disease
# ranked according to their term frequency–inverse document
# classification tool when labeled training data are limited or
# frequency (TF-IDF) defined in equation 1. The list returned was
# unavailable.
# similar to a medical differential diagnosis (a ranked list of
# An overview of our method is shown in Figure 2. The backbone possible diagnoses that could cause a patient’s illness). The
# of CliniqIR is its knowledge base. Once the knowledge base is medical condition with the highest TF-IDF score was predicted
# built, we can query the system to provide a list of probable as the most likely diagnosis. We provide a detailed description
# diagnoses. In this study, a clinical narrative with a patient’s of the individual processing steps in the following sections.
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 3
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# Figure 2. Overview of CliniqIR, the retrieval-based clinical decision support system. PMID: PubMed ID.
# can potentially return multiple abstracts that contain similar
# Concept Extraction and Indexing
# information in response to a given query, resulting in concept
# We extracted unique medical concepts (conditions) from each dictionaries of ≥2 abstracts containing similar concepts. Multiple
# PubMed abstract using QuickUMLS, described in the occurrences could indicate the relevance of a concept across
# Knowledge Extraction Using QuickUMLS section. Medical abstracts. To account for such duplication, we calculated each
# concepts included diseases, symptoms, or any information about unique concept’s recurrence, or term frequency (TF), across the
# a medical procedure. Subsequently, we built the knowledge list. The TF of a concept across a list of abstracts would be 1 if
# base of the retrieval system by indexing each abstract and its it appeared in only 1 abstract. If it appeared in 2 abstracts, its
# corresponding article title, article ID, and a concept dictionary TF would become 2, and so on. Calculating the recurrence of
# that contained all the unique concepts mentioned in that abstract. concepts across the top-100 list resulted in a new list that
# Indexing involves storing and organizing data to enable efficient contained medical concepts and their TFs. These medical
# IR at search time. Using the index of PubMed abstracts, the concepts were regarded as labels and used for classification
# model inputs a patient’s notes as a query and returns relevant purposes. Thus, each unique concept became a potential
# information from the indexed abstracts as an output. Figure 2 diagnosis, and the TF of each concept is subsequently used for
# provides visual details. ranking purposes in equation 1. Textbox 1describes the concepts
# the model returned (in no order of importance) after the retrieval
# Querying and Retrieval
# stage given a set of queries processed using QuickUMLS. The
# Once the index was built, we submitted queries to the retrieval
# list was filtered for a simple illustration. As mentioned
# system. The Retrieval System Implementationsection provides
# previously, concepts are biomedical terms that include
# more details. After we submitted a query, the system returned
# symptoms, signs, and diseases, among other things. On the other
# a list of abstracts and their corresponding attributes (dictionary
# hand, a diagnosis could represent a disease, an injury, a
# of concepts, article title, and article ID number) ranked
# neoplastic process, or a medical term describing a condition a
# according to query relevance. For each query, we selected the
# patient is experiencing. Therefore, to account for a wide range
# top 100 abstracts because the top few documents are most likely
# of possible diagnoses, we kept all concepts in the label
# to contain relevant query information.
# generation phase, and we considered a concept as a diagnosis
# Label Generation when it matched the ground truth. Therefore, in this paper, we
# use conceptsand diagnosesinterchangeably.
# After the querying operation, we focused on the extracted
# concepts of the top 100 abstracts. The previous retrieval phase
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 4
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# Textbox 1. The output returned by the retrieval-based model (CliniqIR) given a query.
# Query and concepts retrieved (labels)
# • Abdominal pain, bloating, rectal bleeding, weight loss, anxiety, disruptive thoughts, and suicidality: “generalized anxiety disorder,” “panniculitis,”
# “chronic abdominal pain,” “Burkitt’s lymphoma,” and “Whipple’s disease”
# • Chest pain, radiation to neck, dyslipidemia, lung crackles, bradycardia, and ST elevation: “acute myocardial infarction,” “acute coronary syndrome,”
# “coronary artery disease,” “myocardial ischemia,” “myopericarditis,” and “myocardial infarctions”
# • Night sweats, abdominal pain (pleuritic), nausea, loose stools, lymphadenopathy (inguinal), plaques, leucopenia, neutrophilia, and elevated
# (Angiotensin converting enzyme) ACE: “sarcoidosis,” “lymphomas,” “lymph node,” “tuberculosis,” “lupus erythematosus,” “Rosai-Dorfman
# disease,” and “Kikuchi-Fujimoto disease”
# on structured knowledge bases; however, most computable
# Ranking and Predictions
# knowledge bases are not freely accessible.
# It is important to note that our model differs from traditional
# Inspired by previous research, we used abstracts from PubMed
# classification schemes. In our case, the observed mappings
# articles as an unstructured collection of knowledge resources
# between patients’ notes and ground-truth diagnoses are not
# to guide the prediction of diagnoses for all our experiments. An
# provided for learning purposes. Therefore, a list of relevant
# abstract may contain information about a specific condition, its
# diagnoses (a subset of the retrieved concepts) must be generated
# signs, or its symptoms. Some abstracts include medical case
# independently for each query. However, as the diagnosis list is
# reports, whereas others may contain information about a medical
# not generated based on ground truth, it may contain information
# device. To build a retrieval system grounded in reliable
# that is not relevant to the data set to be evaluated. For example,
# information, we leveraged the vast collection of abstracts in the
# given a data set with 3 possible ground-truth
# PubMed database. PubMed, maintained by the National Library
# diagnoses—lymphoma, coronary artery disease, and
# of Medicine, houses >33 million citations for biomedical
# gastroenteritis—the model might return concepts such as
# literature, encompassing life science journals and books dating
# coronary artery disease, myocardial infarction, and chest pain
# back to 1946. However, the number of abstracts available per
# in the label retrieval phase for a query whose ground truth is
# condition varies considerably. Therefore, for our core
# coronary artery disease. To address this and ensure a fair
# experiments, we implemented a 100-abstract inclusion threshold
# comparison with other classification models, we filtered the
# for diagnoses (Multimedia Appendix 1).
# retrieved concepts during the evaluation and only kept diagnoses
# that were part of the ground truth. Therefore, in the Knowledge Extraction Using QuickUMLS
# aforementioned example, we filtered out myocardial infarction
# and chest pain. Then, we assigned ranks to the remainder of the Overview
# diagnoses in the list using the TF-IDF function shown in QuickUMLS [31] is an unsupervised medical concept extraction
# equation 1: tool that detects mentions of medical entities such as diseases,
# symptoms, and other medical concepts from unstructured text.
# TFIDF(c,a,d) = TF(c,a).IDF(c,d) (1)
# Given a document, QuickUMLS matches each possible token
# Knowledge Resources: PubMed Abstracts in the document against concepts in the UMLS [28]. In this
# study, we used QuickUMLS for 2 different purposes.
# Over the years, research in predictive modeling for diagnostic
# decision support has witnessed enormous success in transfer Extraction
# learning, particularly where a model leverages an auxiliary data
# We used QuickUMLS to extract unique biomedical concepts
# source (often a knowledge base) to perform several predictive
# from each PubMed abstract. A concept can be any medical term,
# tasks. Some studies [7,22,32] have used resources such as
# including a diagnosis or symptom. As shown in Figure 3, each
# Wikipedia and PubMed [29] to create systems that perform
# biomedical term in a text is a concept with a corresponding
# classification tasks or retrieve useful articles with specific
# unique alphanumeric identifier (concept ID) in the UMLS
# information. In contrast, most early DDSSs [1,33] were built
# vocabulary. We kept all the concepts associated with each
# abstract in a dictionary.
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 5
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# Figure 3. Outputs from the QuickUMLS tool developed by Soldani and Goharian [33] showing: (A) a graph of extracted concepts and their concept
# unique identifier (CUI) for a specific input text; the underlined texts are considered important words, and their corresponding Unified Medical Language
# System terms and CUIs are returned, (B) a query processing pipeline. Each text marked with a strike-through is filtered out to obtain a query.
# Dense Retriever
# Filtering
# Unlike sparse retrievers, which represent queries as word
# We also used QuickUMLS as a data preprocessor to filter out
# frequencies, dense retrievers capture the semantic meaning and
# noisy, uninformative, and nonclinical terms, such as stop words,
# relationships within the text using dense embedding vectors.
# from a patient’s clinical note, resulting in a query that contained
# This allows for retrieval based on similarity, usually calculated
# only medical terms. Citing the input text example in Figure 3,
# through maximum inner-product search. To implement this
# the outcome of the filtering operation was “rashes fever hand
# a p p r o a c h , w e l eve r a g e d t h e
# skin Kikuchi-Fujimoto disease symptoms.” This filtering step
# Medical Contrastive Pre-trained Transformers (MedCPT) [36],
# is equivalent to keeping only the QuickUMLS-recognized
# a state-of-the-art biomedical retrieval system in a zero-shot
# medical terms and concepts.
# setting using its default parameters. Section S1 and Figure S1
# Retrieval System Implementation in the Multimedia Appendix 1provides details on the parameter
# settings for both retrieval systems.
# Overview
# Pretrained Transformer Models
# CliniqIR is designed to be highly adaptable to arbitrary IR
# systems. This flexibility ensures the model’s ability to work In this study, we used 2 well-known methods, namely,
# across various retrieval methods, adapting to the resources supervised fine-tuning and zero-shot learning, to harness the
# available. In this study, we performed experiments on a sparse benefits of transfer learning from 6 pretrained clinical and
# and a dense retriever. biomedical language models. The models we used are
# ClinicalBERT, PubMed Bidirectional Encoder Representations
# Sparse Retriever
# from Transformers (PubMedBERT), Scientific Bidirectional
# We built our knowledge base by indexing PubMed abstracts Encoder Representations from Transformers (SciBERT),
# and their concepts using Apache Lucene (Apache Software Self-alignment Pretrained Bidirectional Encoder Representations
# Foundation [34]), which enables users to search this index with from Transformers (SapBERT), cross-lingual knowledge-infused
# queries ranging from single words to sentences. The relevance medical term embedding (CODER) and MedCPT. We describe
# of an abstract to a query is determined by a similarity score, them briefly in the follows:
# with Lucene’s default “BM25” [35] function estimating the
# ClinicalBERT Model
# best-matching abstract.
# The ClinicalBERT [37] is an extension of Biomedical
# Bidirectional Encoder Representations from Transformers [38]
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 6
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# trained further on discharge summary notes from the Medical deliver state-of-the-art performance. Unfortunately, labeled data
# Information Mart for Intensive Care III (MIMIC-III) database are expensive to generate. This requirement makes it impractical
# [39]. It was designed to handle the complexity and nuances of to use a supervised fine-tuned model to diagnose those diseases
# clinical text. without (many) notes for training. Hence, we used this method
# to make predictions only when training data were available.
# PubMedBERT Model
# Zero-Shot Learning
# PubMedBERT [40] was specifically designed to capture
# domain-specific knowledge present in biomedical literature. It Given our focus on predicting diagnoses with few or 0 training
# was initialized from Bidirectional Encoder Representations samples, we included zero-shot learning methods as baselines.
# From Transformers (BERT) and trained further on the collection Leveraging the high quality of the aforementioned pretrained
# of PubMed abstracts. transformer embeddings, we adopted a zero-shot strategy by
# classifying patients’notes based on their semantic similarity to
# SciBERT Model
# potential diagnoses. This can be achieved by using pretrained
# SciBERT [41] is a BERT-based language model pretrained on models as biencoders [18,44]. Using this approach, we
# 1.14 million full-text papers from Semantic Scholar. The corpus accounted for the diagnosis classes (classes without training
# domain cuts across the field of computer science and the samples) that the supervised fine-tuned models could not handle.
# biomedical space.
# Given a patient’s note (our query) and the list of candidate
# SapBERT Model diagnoses as labels, we used different variants of BERT as
# SapBERT [42] is also a BERT-based model initialized from biencoders to encode queries and the full names of all
# PubMedBERT. SapBERT was further pretrained on UMLS ground-truth diagnoses to produce their respective representation
# [28], which consists of a wide range of biomedical ontologies vectors separately. Next, we computed their cosine similarity
# for >4 million concepts. score and ranked each diagnosis for each query according to
# this score. The diagnosis with the highest cosine similarity
# CODER Model
# became the model’s most confident diagnostic prediction (refer
# CODER [43] is another BERT-based model formulated to to Multimedia Appendix 1for more details).
# generate biomedical embeddings. It was also initialized from
# Model Ensemble: Reciprocal Rank Fusion
# PubMedBERT. CODER was further pretrained using the
# concepts from the UMLS [28] and optimized to increase the The label retrieval process allowed the CliniqIR (retrieval-based
# embedding similarities between terms with the same concept model) to diagnose unseen conditions regardless of training
# unique identifier. data availability. This property is beneficial for diagnoses with
# little or no training data. On the other hand, a supervised
# MedCPT Model
# fine-tuned model can draw much deeper insights from available
# MedCPT [36] is a contrastive pretrained PubMedBERT-based historical case data. We adopted an ensemble strategy to
# model also formulated to generate biomedical text embeddings combine the advantages of both paradigms.
# for multiple tasks.
# In IR and general machine learning, ensemble strategies combine
# Supervised Fine-Tuning results from multiple models to produce a single joint output.
# Ideally, the ensemble model should produce a new output whose
# Given a set of patients’notes (hereinafter also referred to as
# performance is superior to that of the individual constituent
# notes) as inputs and their corresponding diagnoses as outputs,
# models. Several studies [32,45,46] have shown that
# we fine-tuned the pretrained models in a supervised fashion to
# high-performance gains can be achieved through model
# classify diagnoses by feeding in a series of notes and their
# ensembling. One of the simplest ways to build such a model is
# corresponding ground-truth diagnoses. Each note was a textual
# to focus on applying a reranking heuristic to the ranks of each
# document describing a patient’s health condition and medical
# item in a model’s output list. Hence, we collected the ranked
# history. The ground-truth diagnosis of a note was the
# list of diagnoses from a CliniqIR model and that of the
# corresponding health condition of the patient. Multimedia
# best-performing supervised fine-tuned model, ClinicalBERT,
# Appendix 1provides details of the models’parameter settings.
# and combined the 2 lists. We then applied a modified version
# After fine-tuning, given a test set of notes, a model assigned
# of the reciprocal rank fusion (RRF) [45] algorithm using
# probabilities to each ground-truth diagnosis for each note. The
# equation 2 to merge their results and produce a single, final
# diagnosis with the highest probability corresponded to the
# output list. Given a set Cof concepts(diagnoses) to be ranked
# model’s most confident prediction. We assigned ranks to each
# and a set of rankings Rfor all concepts obtained from each
# diagnosis in the order of their decreasing probability score for
# ensemble member (CliniqIR and ClinicalBERT), we computed
# all our predictions. These ranks were further used to compute
# the RRF score for each concept (c∈ C) as follows:
# the mean reciprocal rank (MRR) for model evaluation (refer to
# the Evaluation Metricssection for details). We justify the use
# of ranking output probabilities across classes to compute the
# MRR because the probabilities generated by the classifier
# (2)
# represent the classifier’s confidence in predicting each incidence.
# In the aforementioned equation, “r ∈ R” is the rank of concept
# Supervised fine-tuning requires diagnosis-specific training data
# caccording to an ensemble member. We summed up the
# (availability of historic patient notes for each diagnosis) to
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 7
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# individual ranks of a concept from each ensemble member “r(c)” ICD-9-CM (International Classification of Diseases, Ninth
# with k and computed the inverse. Previous work by Cormack Revision, Clinical Modification), codes. We worked with the
# et al [45] reported that setting kto 60 was the near-optimal choice discharge notes for all experiments because they document a
# for most of their experiments. Hence, we set k to 60 for all free-text synopsis of a patient’s hospital stay from admission
# experiments. When concepts (diagnoses) had more than one to discharge. In MIMIC-III, each discharge note is mapped to
# training sample, we selected their individual ranks rfrom each multiple diagnoses ranked according to priority. We considered
# ensemble member to compute the RRF score; otherwise, we the highest-priority diagnosis to be the admission’s ground-truth
# selected ranks from the CliniqIR model. We used the RRF diagnosis (and prediction target). We excluded admissions
# algorithm due to some key advantages: (1) it is a simple primarily for birth and pregnancy as they did not represent a
# unsupervised method that eliminates the need for training primary pathological diagnosis. After preprocessing, the
# samples, and (2) it effectively combines the results from various discharge notes contained 2634 unique ICD-9-CMdiagnoses.
# models without reliance on a weighting or voting mechanism. We mapped these ICD-9-CM diagnoses to their corresponding
# UMLS concept IDs to calculate their TF across the knowledge
# Experimental Setup
# resource (PubMed abstracts). The resulting unique diagnoses
# Data Sources were associated with notes ranging from thousands of
# occurrences of frequent conditions, such as coronary
# DC3 Data Set
# atherosclerosis and aortic valve disorders, to rare ones, such as
# The DC3 data set [30] was designed specifically for the Evans syndrome and ehrlichiosis, with just a single instance
# evaluation of diagnostic support systems. The data set comprises forming a long-tailed distribution. A total of 902 diagnoses fell
# 30 rare and difficult-to-diagnose cases compiled and solved by into the singleton category. One discharge note representing a
# clinical experts in the New England Journal of MedicineCase specific diagnosis is insufficient to train and test a model. Thus,
# Challenges. This data set lacks large, labeled training data, but we reserved all diagnoses with only 1 available note for model
# it covers a wide range of diagnostic cases for various specialties. testing. For diagnoses with <5 note samples, we reserved 1
# Therefore, we used this data set to determine the applicability sample for testing, and the rest were included in model training.
# of CliniqIR for diagnostic inference when the underlying patient We split the remainder of the data set (instances of diagnoses
# condition is rare. Each case is a patient’s note and its with ≥5 associated notes) into training, validation, and testing
# corresponding true diagnosis written as free text. We mapped sets in the ratio 70:15:15; this split resulted in the training set
# the true diagnoses to their UMLS concept IDs to produce test containing notes representing 1732 unique diagnoses and the
# labels for evaluation consistency. When we did not find an exact test set containing notes representing a total of 2634 unique
# matching term for a diagnosis, we considered the closest match diagnoses (refer to Multimedia Appendix 1 for more details).
# returned by the UMLS browser. During the preprocessing step, For models that did not require training (eg, the retrieval model),
# we found that some cases in the DC3 data set had multiple terms we used the validation and training sets for hyperparameter
# representing a ground-truth diagnosis, making it difficult to find tuning purposes and the test set for final model evaluations.
# a single UMLS concept ID for such cases. To ensure an accurate
# Baselines
# mapping with the UMLS concept IDs, we split such cases into
# separate terms. For example, the case “Acute and chronic Previous studies and competitions, such as the TREC clinical
# cholecystitis and extensive cholelithiasis with transmural decision support track, have emphasized the development and
# gallbladder inflammation” was split into 2 separate terms: evaluation of IR systems to aid clinical decision-making. While
# “Acute and chronic cholecystitis” and “Extensive cholelithiasis these systems are commonly used for evidence-based literature
# with transmural gallbladder inflammation.” Then, we mapped searches, our study explored their adaptation for direct
# each case to its corresponding UMLS concept ID. Next, we literature-guided diagnosis prediction. Although a direct
# computed the document frequency of all the true diagnoses comparison to the systems in the TREC clinical decision support
# (now represented as concepts) across all PubMed abstracts. In track was not possible, insights gained from these competitions
# these cases, either of the concepts could be considered as the informed the engineering of our retrieval system. To evaluate
# ground truth. As the data did not contain sufficient notes to train our model, we used 2 transfer learning techniques—supervised
# a model, we formulated this task as a zero-shot fine-tuning and zero-shot classification methods (refer to the
# multiclassification problem. Specifically, we expected a model Pretrained Transformer Models section)—because of their
# to predict the underlying condition given a patient’s note without performance in scenarios where labeled data are limited or
# labeled training data. unavailable. In addition, some studies [47-49] have shown
# pretrained language models to attain superior performance to
# MIMIC-III Data Set
# that of count vector–based models and traditional supervised
# The MIMIC-III [39] is a freely accessible medical database that methods in various medical tasks. We used “Z” to identify when
# contains information on >50,000 intensive care unit patients. models were used in a zero-shot classification setting, an “S”
# The data include laboratory events, vital sign measurements, for supervised fine-tuning, and “CliniqIR” when models were
# clinical observations, notes, and diagnoses structured as used in a retrieval setting. Table 1provides details.
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 8
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# Table 1. Overview of the experiments conducted using the different models and their task description.
# Experiment Models used Task description
# Retrieval-based experiments BM25aand MedCPTb Models retrieved relevant abstracts to inform diagnostic
# (CliniqIR) predictions.
# Zero-shot experiments (Z) ClinicalBERTc, PubMedBERTd, CODERe, SapBERTf, Models classified diseases in a zero-shot setting without
# and MedCPT previous task-specific training.
# Supervised experiments (S) ClinicalBERT Models were fine-tuned using labeled data for enhanced
# disease prediction accuracy.
# aBM25: Best Match 25.
# bMedCPT: Medical Contrastive Pretrained Transformers.
# cClinicalBERT: Clinical Bidirectional Encoder Representations from Transformers.
# dPubMedBERT: PubMed Bidirectional Encoder Representations from Transformers.
# eCODER: cross-lingual knowledge-infused medical term embedding.
# fSapBERT: Self-alignment Pretrained Bidirectional Encoder Representations from Transformers.
# (3)
# Evaluation Metrics
# where |Q|denotes the total number of queries and denotes the
# In our experiments, each model returned a ranked list of
# rank of the correct diagnosis. We also calculated the mean
# diagnoses analogous to a ranked list of differential diagnoses
# average precision (MAP) to evaluate the balance between
# formulated by a medical expert. Given a query and a list of
# precision and recall of the retrieval systems (for details, refer
# ranked items produced by a model, a simple classification
# to Multimedia Appendix 1).
# accuracy metric tracks whether the model made the correct
# prediction at the top of the list. Instead, we used the MRR [50] Ethical Considerations
# because it told us where the true diagnosis was placed in the No ethics approval was pursued for this research, given that the
# list in equation 3. If a model returned the reference diagnosis data were publicly accessible and deidentified.This aligns with
# at rank 1 (ie, at the top of the list), the reciprocal rank (RR) was the guidelines outlined by the US Department of Health and
# 1; if the most appropriate item was at rank 2, then the RR was Human Services, Office for Human Research Protections,
# 0.5. The RR decreases as the relevant item moves farther down §46.101 (b)(4) [51].
# the list. We calculated the MRR by computing the average RR
# across admissions. An MRR of 1 meant that the model returned Results
# the correct diagnosis at the top of its list for every patient, and
# an MRR of 0 implied that the model never produced a correct CliniqIR Models Retrieved Useful Literature and
# diagnosis. Mathematically, the MRR can be represented as Meaningful Concepts
# follows:
# Table 2 showcases qualitative results for 3 selected queries,
# displaying the top 3 documents retrieved by the CliniqIR model.
# Notably, the retrieved articles and their corresponding concepts
# demonstrated clear relevance to the ground-truth diagnoses of
# the respective queries.
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 9
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# Table 2. Qualitative overview of the top documents and concepts retrieved for 3 selected queries along with their respective correct concepts. This
# table illustrates the types of results our system generates for each query, showing the alignment with the ground-truth concepts.
# Ground-truth diagnosis, and top 3 documents Retrieved concepts
# 1. Viral pneumonia
# Relevant article 1—PMIDa15336585: Cases from the {“C1956415”: [“paroxysmal nocturnal dyspnea”], “C0239295”: [“esophageal candidi-
# Osler Medical Service at Johns Hopkins University. Di- asis”], “C0236053”: [“mucosal ulcers”], “C1535939”: [“Pneumocystis”], “C0031256”:
# agnosis: P. carinii pneumonia and primary pulmonary [“petechiae”], “C0006849”: [“thrush”], “C0011168”: [“dysphagia”]}
# sporotrichosis
# Relevant article 2—PMID 32788269: A 16-Year-Old {“C0746102”: [“chronic lung disease”], “C0004096”: [“asthma”], “C0009443”:
# Boy with Cough and Fever in the Era of COVID-19 [“cold”], “C0206750”: [“Coronavirus”], “C0018609”: [“h disease”]}
# Relevant article 3—PMID 30225154: Meningococcal {“C3714636”: [“pneumonias”], C1535950”: [“GI inflammation”]}
# Pneumonia in a Young Healthy Male
# 2. Hypoparathyroidism
# Relevant article 1—PMID 34765380: A Challenging Case {“C0220983”: [“metabolic alkalosis”], “C0151723”: [“hypomagnesemia”],
# of Persisting Hypokalemia Secondary to Gitelman Syn- “C0020599”: [“hypocalciuria”], “C0014335”: [“enteritis”], “C0012634”: [“Diagnosis”],
# drome “C0235394”: [“wasting”], “C0271728”: [“Hyperreninemic hyperaldosteronism”],
# “C0268450”: [“gitelman syndrome”], “C3552462”: [“Tubulopathy”]}
# Relevant article 2—PMID 27190662: Suppression of {“C0151723”: [“hypomagnesemia”], “C0030554”: [“paresthesias”], “C0020598”:
# Parathyroid Hormone in a Patient with Severe Magnesium [“hypocalcemias”], “C0020626”: [“Low parathyroid hormone”], “C0030517”:
# Depletion [“Parathyroid”], “C0033806”: [“pseudo hypoparathyroidism”]}
# Relevant article 3—PMID 28163524: Afebrile Seizures {“C0020626”: [“Hypoparathyroidism”], “C0012236”: [“DiGeorge syndrome”],
# as Initial Symptom of Hypocalcemia Secondary to Hy- “C0863106”: [“afebrile seizures”], “C0030353”: [“papilledema”], “C0020598”:
# poparathyroidism [“Hypocalcemias”], “C0012634”: [“Diagnosis”], “C0042870”: [“Vitamin D deficien-
# cy”]}
# 3. Intracerebral hemorrhage
# Relevant article 1—PMID 9125737: A 36-year-old {“C0020564”: [“enlargement”], “C0019080”: [“hemorrhage”]}
# woman with acute onset left hemiplegia and anosognosia
# Relevant article 2—PMID 25830084: Multiple extra-is- {“C2937358”: [“Intracerebral hemorrhage”], “C0151699”: [“intracranial hemorrhage”],
# chemic hemorrhages following intravenous thrombolysis “C0019080”: [“hemorrhages”], “C0020564”: [“enlargement”], “C0021308”: [“infarct”],
# in a patient with Trousseau syndrome: case study. “C0022116”: [“ischemia”]}
# Relevant article 3—PMID 1434057: A case of recurrent {“C0472376”: [“thalamic hemorrhage”], “C2937358”: [“cerebral hemorrhage”],
# cerebral hemorrhage considered to be cerebral amyloid “C0019080”: [“bleeding”], “C0023182”: [“cerebrospinal fluid leak”]}
# angiopathy by cerebrospinal fluid examination.
# aPMID: PubMed ID.
# 3 shows the MRR of the chosen models on the DC3 data set.
# CliniqIR Models Yielded State-of-the-Art Performance
# Even with the supporting assumption that the range of possible
# for Rare and Complex Diagnoses
# diagnoses was known to the pretrained models, the CliniqIR
# We examined the retrieval-based models’ (CliniqIR) models outperformed them with an MRR of 0.35 and 0.32 for
# performance on the DC3 data set to show their applicability for CliniqIR_BM25 and CliniqIR_MedCPT, respectively. This
# rare and complex diagnostic cases. The absence of training data means that, on average, CliniqIR_BM25 and CliniqIR_MedCPT
# for this data set implied that supervised learning would not be were more likely to return the correct diagnosis within the top
# applicable and the models could only make predictions in an 3 predictions for a case.
# unsupervised or zero-shot setting. Hence, on this data set, we
# The MRR scores of the pretrained zero-shot methods were
# compared the CliniqIR models’performance to that of pretrained
# similar to one another but markedly lower; the scores were 0.15,
# transformers in a zero-shot setting. In contrast to the CliniqIR
# 0.22, 0.25, 0.25, 0.24, and 0.18 for ClinicalBERT,
# model, which creates its own set of labels, we supplied the
# PubMedBERT, SciBERT, CODER, SapBERT, and MedCPT,
# pretrained transformers with a range of potential diagnoses for
# respectively. Our results show that the CliniqIR models are
# each query to enable zero-shot predictions. This gave the models
# capable of making useful predictions in the case of rare and
# a significant advantage over their use in a real-world setting,
# complex diagnoses with limited or no training data availability.
# where such information would not be readily available. Table
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 10
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# Table 3. Performance evaluation of the models on the DC3 data sets across all case. The retrieval-based models, denoted using “CliniqIR” gave the
# best overall performance compared to the zero-shot models, denoted using “Z.”
# Model used Mean reciprocal rank
# ClinicalBERTa(Z) 0.15
# PubMedMERTb(Z) 0.22
# SciBERTc(Z) 0.25
# CODERd(Z) 0.25
# SapBERTe(Z) 0.24
# CliniqIR_BM25 0.35f
# MedCPTg(Z) 0.18
# CliniqIR_MedCPT 0.32
# aClinicalBERT: Clinical Bidirectional Encoder Representations from Transformers.
# bPubMedBERT: PubMed Bidirectional Encoder Representations from Transformers.
# cSciBERT: Scientific Bidirectional Encoder Representations from Transformers.
# dCODER: cross-lingual knowledge-infused medical term embedding.
# eSapBERT: Self-alignment Pretrained Bidirectional Encoder Representations from Transformers.
# fHighest mean reciprocal rank is italicized.
# gMedCPT: Medical Contrastive Pre-trained Transformers.
# ClinicalBERT as our supervised baseline for the remainder of
# Performance on MIMIC-III
# our experiments.
# Supervised Prediction Models Failed at Making Rare
# After training ClincalBERT, we tested it on different clinical
# Diagnoses
# note frequency–based categories (Table 4). In Table 4, we
# When training data are available, supervised models are observed that the MRR score of the ClinicalBERT model was
# preferred. Thus, we investigated the effectiveness of a higher for diagnosis categories with many training examples
# supervised learning approach for a highly imbalanced data set (>10 notes). In addition, in the data set category with 1 to 10
# such as MIMIC-III. We fine-tuned the pretrained models to notes available per diagnosis (1<notes≤10), ClinicalBERT
# predict diagnoses using available clinical notes. Diagnoses were obtained a low MRR score of 0.07. An MRR of 0.08 indicates
# categorized based on the frequency of associated notes to show that, on average, ClinicalBERT returned the correct diagnosis
# how training data availability affects a supervised model’s for a case among its top 13 predictions for these diagnoses.
# predictive capacity. A total of 902 diagnoses had no training While the model could not perform predictions for 902
# ...
# code to implement this work is also available [55].
# Conflicts of Interest
# None declared.
# Multimedia Appendix 1
# Details on model implementation, configuration, and performance comparisons across various data sets and configurations.
# [DOCX File , 5518 KB-Multimedia Appendix 1]
# References
# 1. Barnett GO, Cimino JJ, Hupp JA, Hoffer EP. DXplain: an evolving diagnostic decision-support system. JAMA. Jul 03,
# 1987;258(1):67-74. [doi: 10.1001/jama.1987.03400010071030]
# 2. Khoong EC, Nouri SS, Tuot DS, Nundy S, Fontil V, Sarkar U. Comparison of diagnostic recommendations from individual
# physicians versus the collective intelligence of multiple physicians in ambulatory cases referred for specialist consultation.
# Med Decis Making. Apr 2022;42(3):293-302. [FREE Full text] [doi: 10.1177/0272989X211031209] [Medline: 34378444]
# 3. Barnett ML, Boddupalli D, Nundy S, Bates DW. Comparative accuracy of diagnosis by collective intelligence of multiple
# physicians vs individual physicians. JAMA Netw Open. Mar 01, 2019;2(3):e190096. [FREE Full text] [doi:
# 10.1001/jamanetworkopen.2019.0096] [Medline: 30821822]
# 4. Sutton RT, Pincock D, Baumgart DC, Sadowski DC, Fedorak RN, Kroeker KI. An overview of clinical decision support
# systems: benefits, risks, and strategies for success. NPJ Digit Med. Feb 06, 2020;3:17. [FREE Full text] [doi:
# 10.1038/s41746-020-0221-y] [Medline: 32047862]
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 15
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# 5. Ramnarayan P, Tomlinson A, Rao A, Coren M, Winrow A, Britto J. ISABEL: a web-based differential diagnostic aid for
# paediatrics: results from an initial performance evaluation. Arch Dis Child. May 2003;88(5):408-413. [FREE Full text]
# [doi: 10.1136/adc.88.5.408] [Medline: 12716712]
# 6. Müller L, Gangadharaiah R, Klein SC, Perry J, Bernstein G, Nurkse D, et al. An open access medical knowledge base for
# community driven diagnostic decision support system development. BMC Med Inform Decis Mak. Apr 27, 2019;19(1):93.
# [FREE Full text] [doi: 10.1186/s12911-019-0804-1] [Medline: 31029130]
# 7. Prakash A, Zhao S, Hasan S, Datla V, Lee K, Qadir A, et al. Condensed memory networks for clinical diagnostic inferencing.
# Proc AAAI Conf Artif Intell. Feb 12, 2017;31(1). [doi: 10.1609/aaai.v31i1.10964]
# 8. Venugopalan J, Tong L, Hassanzadeh HR, Wang MD. Multimodal deep learning models for early detection of Alzheimer's
# disease stage. Sci Rep. Feb 05, 2021;11(1):3254. [FREE Full text] [doi: 10.1038/s41598-020-74399-w] [Medline: 33547343]
# 9. Liu J, Zhang Z, Razavian N. Deep EHR: chronic disease prediction using medical notes. arXiv. Preprint posted online
# August 15, 2018. [FREE Full text]
# 10. Gehrmann S, Dernoncourt F, Li Y, Carlson ET, Wu JT, Welt J, et al. Comparing deep learning and concept extraction
# based methods for patient phenotyping from clinical narratives. PLoS One. Feb 15, 2018;13(2):e0192360. [FREE Full text]
# [doi: 10.1371/journal.pone.0192360] [Medline: 29447188]
# 11. Jain D, Singh V. Feature selection and classification systems for chronic disease prediction: a review. Egypt Inform J. Nov
# 2018;19(3):179-189. [doi: 10.1016/j.eij.2018.03.002]
# 12. Singh Kohli P, Arora S. Application of machine learning in disease prediction. In: Proceedings of the 4th International
# Conference on Computing Communication and Automation. 2018. Presented at: ICCCA 2018; December 14-15, 2018;
# Greater Noida, India. [doi: 10.1109/ccaa.2018.8777449]
# 13. Abdullahi T, Nitschke G, Sweijd N. Predicting diarrhoea outbreaks with climate change. PLoS One. Apr 19,
# 2022;17(4):e0262008. [FREE Full text] [doi: 10.1371/journal.pone.0262008] [Medline: 35439258]
# 14. Alon G, Chen E, Savova G, Eickhoff C. Diagnosis prevalence vs. efficacy in machine-learning based diagnostic decision
# support. arXiv. Preprint posted online June 24, 2020. [FREE Full text]
# 15. Rios A, Kavuluru R. Few-shot and zero-shot multi-label learning for structured label spaces. In: Proceedings of the 2018
# Conference on Empirical Methods in Natural Language Processing. 2018. Presented at: EMNLP 2018; October 31-November
# 4, 2018; Brussels, Belgium. [doi: 10.18653/v1/d18-1352]
# 16. Zhao Y, Wong ZS, Tsui KL. A framework of rebalancing imbalanced healthcare data for rare events' classification: a case
# of look-alike sound-alike mix-up incident detection. J Healthc Eng. May 22, 2018;2018:6275435. [FREE Full text] [doi:
# 10.1155/2018/6275435] [Medline: 29951182]
# 17. Romera-Paredes B, Torr PH. An embarrassingly simple approach to zero-shot learning. In: Feris R, Lampert C, Parikh D,
# editors. Visual Attributes. Cham, Switzerland. Springer; Mar 22, 2017.
# 18. Veeranna SP, Nam J, Mencía EL, Furnkranz J. Using semantic similarity for multi-label zero-shot classification of text
# documents. In: Proceedings of the European Symposium on Artificial Neural Networks, Computational Intelligence and
# Machine Learning. 2016. Presented at: ESANN 2016; April 27-29, 2016; Bruges, Belgium.
# 19. Brown TB, Mann B, Ryder N, Subbiah M, Kaplan J, Dhariwal P, et al. Language models are few-shot learners. arXiv.
# Preprint posted online May 28, 2020. [FREE Full text]
# 20. Sanh V, Webson A, Raffel C, Bach SH, Sutawika L, Alyafeai Z, et al. Multitask prompted training enables zero-shot task
# generalization. arXiv. Preprint posted online October 15, 2021. [FREE Full text]
# 21. Li Y, Chao X. Semi-supervised few-shot learning approach for plant diseases recognition. Plant Methods. Jun 27,
# 2021;17(1):68. [FREE Full text] [doi: 10.1186/s13007-021-00770-1] [Medline: 34176505]
# 22. Zhao Y, Lai H, Yin J, Zhang Y, Yang S, Jia Z, et al. Zero-shot medical image retrieval for emerging infectious diseases
# based on meta-transfer learning - worldwide, 2020. China CDC Wkly. Dec 25, 2020;2(52):1004-1008. [FREE Full text]
# [doi: 10.46234/ccdcw2020.268] [Medline: 34594825]
# 23. Soldaini L, Cohan A, Yates A, Goharian N, Frieder O. Retrieving medical literature for clinical decision support. In:
# Proceedings of the 37th European Conference on IR Research. 2015. Presented at: ECIR 2015; March 29-April 2, 2015;
# Vienna, Austria. [doi: 10.1007/978-3-319-16354-3_59]
# 24. Hasan SA, Ling Y, Liu J, Farri O. Using neural embeddings for diagnostic inferencing in clinical question answering. In:
# Proceedings of the Twenty-Fourth Text REtrieval Conference. 2015. Presented at: TREC 2015; November 17-20, 2015;
# Gaithersburg, MD.
# 25. Hasan SA, Zhu X, Dong Y, Liu J, Farri O. A hybrid approach to clinical question answering. In: Proceedings of the
# Twenty-Third Text REtrieval Conference 2014. 2014. Presented at: TREC 2014; November 19-21, 2014; Gaithersburg,
# MD.
# 26. Text REtrieval Conference (TREC) home page. Text REtrieval Conference (TREC). URL: https://trec.nist.gov/[accessed
# 2024-06-03]
# 27. Naik A, Parasa S, Feldman S, Wang LL, Hope T. Literature-augmented clinical outcome prediction. arXiv. Preprint posted
# online November 16, 2021. [FREE Full text] [doi: 10.18653/v1/2022.findings-naacl.33]
# 28. Bodenreider O. The Unified Medical Language System (UMLS): integrating biomedical terminology. Nucleic Acids Res.
# Jan 01, 2004;32(Database issue):D267-D270. [FREE Full text] [doi: 10.1093/nar/gkh061] [Medline: 14681409]
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 16
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# 29. White J. PubMed 2.0. Med Ref Serv Q. Oct 21, 2020;39(4):382-387. [doi: 10.1080/02763869.2020.1826228] [Medline:
# 33085945]
# 30. Eickhoff C, Gmehlin F, Patel AV, Boullier J, Fraser H. DC3 -- a diagnostic case challenge collection for clinical decision
# support. In: Proceedings of the 2019 ACM SIGIR International Conference on Theory of Information Retrieval. 2019.
# Presented at: ICTIR '19; October 2-5, 2019; Santa Clara, CA. [doi: 10.1145/3341981.3344239]
# 31. Soldaini L, Goharian N. QuickUMLS: a fast, unsupervised approach for medical concept extraction. In: Proceedings of the
# 2nd SIGIR Workshop on Medical Information Retrieval (MedIR). 2016. Presented at: SIGIR 2016; July 21, 2016; Pisa,
# Italy.
# 32. Zhao Z, Jin Q, Chen F, Peng T, Yu S. A large-scale dataset of patient summaries for retrieval-based clinical decision support
# systems. Sci Data. Dec 18, 2023;10(1):909. [FREE Full text] [doi: 10.1038/s41597-023-02814-8] [Medline: 38110415]
# 33. Vardell E, Moore M. Isabel, a clinical decision support system. Med Ref Serv Q. Apr 25, 2011;30(2):158-166. [doi:
# 10.1080/02763869.2011.562800] [Medline: 21534115]
# 34. Welcome to Apache Lucene. Apache Lucene. URL: https://lucene.apache.org/[accessed 2024-06-03]
# 35. Robertson S, Walker S, Hancock-Beaulieu MM, Gatford M, Payne A. Okapi at TREC-4. In: Proceedings of the Fourth
# Text REtrieval Conference. 1995. Presented at: TREC-4 1995; November 1-3, 1995; Gaithersburg, MD.
# 36. Jin Q, Kim W, Chen Q, Comeau DC, Yeganova L, Wilbur WJ, et al. MedCPT: contrastive pre-trained transformers with
# large-scale PubMed search logs for zero-shot biomedical information retrieval. Bioinformatics. Nov 01, 2023;39(11):2023.
# [FREE Full text] [doi: 10.1093/bioinformatics/btad651] [Medline: 37930897]
# 37. Alsentzer E, Murphy J, Boag W, Weng WH, Jindi D, Naumann T, et al. Publicly available clinical BERT embeddings. In:
# Proceedings of the 2nd Clinical Natural Language Processing Workshop. 2019. Presented at: ClinicalNLP 2019; June 7,
# 2019; Minneapolis, MN. [doi: 10.18653/v1/w19-1909]
# 38. Lee J, Yoon W, Kim S, Kim D, Kim S, So CH, et al. BioBERT: a pre-trained biomedical language representation model
# for biomedical text mining. Bioinformatics. Feb 15, 2020;36(4):1234-1240. [FREE Full text] [doi:
# 10.1093/bioinformatics/btz682] [Medline: 31501885]
# 39. Johnson AE, Pollard TJ, Shen LW, Lehman LH, Feng M, Ghassemi M, et al. MIMIC-III, a freely accessible critical care
# database. Sci Data. May 24, 2016;3(1):160035. [FREE Full text] [doi: 10.1038/sdata.2016.35] [Medline: 27219127]
# 40. Gu Y, Tinn R, Cheng H, Lucas M, Usuyama N, Liu X, et al. Domain-specific language model pretraining for biomedical
# natural language processing. ACM Trans Comput Healthcare. Oct 15, 2021;3(1):1-23. [doi: 10.1145/3458754]
# 41. Beltagy I, Lo K, Cohan A. SciBERT: a pretrained language model for scientific text. arXiv. Preprint posted online March
# 26, 2019. [FREE Full text] [doi: 10.18653/v1/d19-1371]
# 42. Liu F, Shareghi E, Meng Z, Basaldella M, Collier N. Self-alignment pretraining for biomedical entity representations.
# arXiv. Preprint posted online October 22, 2020. [FREE Full text] [doi: 10.18653/v1/2021.naacl-main.334]
# 43. Yuan Z, Zhao Z, Sun H, Li J, Wang F, Yu S. CODER: knowledge-infused cross-lingual medical term embedding for term
# normalization. J Biomed Inform. Feb 2022;126:103983. [FREE Full text] [doi: 10.1016/j.jbi.2021.103983] [Medline:
# 34990838]
# 44. Reimers N, Gurevych I. Sentence-BERT: sentence embeddings using Siamese BERT-networks. arXiv. Preprint posted
# online August 27, 2019. [doi: 10.18653/v1/d19-1410]
# 45. Cormack GV, Clarke CL, Buettcher S. Reciprocal rank fusion outperforms condorcet and individual rank learning methods.
# In: Proceedings of the 32nd International ACM SIGIR Conference on Research and Development in Information Retrieval.
# 2009. Presented at: SIGIR '09; July 19-23, 2009; Boston, MA. [doi: 10.1145/1571941.1572114]
# 46. Kurland O, Culpepper J. Fusion in information retrieval: SIGIR 2018 half-day tutorial. In: Proceedings of the 41st International
# ACM SIGIR Conference on Research & Development in Information Retrieval. 2018. Presented at: SIGIR '18; July 8-12,
# 2018; Ann Arbor, MI. [doi: 10.1145/3209978.3210186]
# 47. Mugisha C, Paik I. Comparison of neural language modeling pipelines for outcome prediction from unstructured medical
# text notes. IEEE Access. 2022;10:16489-16498. [doi: 10.1109/access.2022.3148279]
# 48. Yao L, Jin Z, Mao C, Zhang Y, Luo Y. Traditional Chinese medicine clinical records classification with BERT and domain
# specific corpora. J Am Med Inform Assoc. Dec 01, 2019;26(12):1632-1636. [FREE Full text] [doi: 10.1093/jamia/ocz164]
# [Medline: 31550356]
# 49. Shen Z, Schutte D, Yi Y, Bompelli A, Yu F, Wang Y, et al. Classifying the lifestyle status for Alzheimer's disease from
# clinical notes using deep learning with weak supervision. BMC Med Inform Decis Mak. Jul 07, 2022;22(Suppl 1):88.
# [FREE Full text] [doi: 10.1186/s12911-022-01819-4] [Medline: 35799294]
# 50. Craswell N. Mean reciprocal rank. In: Liu L, Özsu MT, editors. Encyclopedia of Database Systems. Boston, MA. Springer;
# 2009.
# 51. Basic HHS Policy for Protection of Human Research Subjects. US Department of Health and Human Services, Office for
# Human Research Protections. URL: https://www.hhs.gov/ohrp/regulations-and-policy/regulations/regulatory-text/index.
# html#46.101
# 52. Abdullahi T, Singh R, Eickhoff C. Learning to make rare and complex diagnoses with generative AI assistance: qualitative
# study of popular large language models. JMIR Med Educ. Feb 13, 2024;10:e51391. [FREE Full text] [doi: 10.2196/51391]
# [Medline: 38349725]
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 17
# XSL FO (page number not for citation purposes)
# •
# RenderXJMIR MEDICAL INFORMATICS Abdullahi et al
# 53. McGauran N, Wieseler B, Kreis J, Schüler YB, Kölsch H, Kaiser T. Reporting bias in medical research - a narrative review.
# Trials. Apr 13, 2010;11(1):37. [FREE Full text] [doi: 10.1186/1745-6215-11-37] [Medline: 20388211]
# 54. Montori VM, Smieja M, Guyatt GH. Publication bias: a brief review for clinicians. Mayo Clin Proc. Dec
# 2000;75(12):1284-1288. [doi: 10.4065/75.12.1284] [Medline: 11126838]
# 55. CliniqIR: retrieval-based diagnostic decision support. GitHub. URL: https://github.com/rsinghlab/CliniqIR[accessed
# 2024-05-31]
# Abbreviations
# BERT: Bidirectional Encoder Representations From Transformers
# ClinicalBERT: Clinical Bidirectional Encoder Representations from Transformers
# CODER: cross-lingual knowledge-infused medical term embedding
# DDSS: diagnostic decision support system
# ICD-9-CM: International Classification of Diseases, Ninth Revision, Clinical Modification
# IR: information retrieval
# MAP: mean average precision
# MedCPT: Medical Contrastive Pre-trained Transformers
# MIMIC-III: Medical Information Mart for Intensive Care III
# MRR: mean reciprocal rank
# PubMedBERT: PubMed Bidirectional Encoder Representations from Transformers
# RR: reciprocal rank
# RRF: reciprocal rank fusion
# SapBERT: Self-alignment Pretrained Bidirectional Encoder Representations from Transformers
# SciBERT: Scientific Bidirectional Encoder Representations from Transformers
# TF: term frequency
# TF-IDF: term frequency–inverse document frequency
# TREC: text retrieval conference
# UMLS: Unified Medical Language System
# Edited by C Lovis; submitted 25.06.23; peer-reviewed by J Zheng, Q Jin; comments to author 06.02.24; revised version received
# 10.03.24; accepted 17.04.24; published 19.06.24
# Please cite as:
# Abdullahi T, Mercurio L, Singh R, Eickhoff C
# Retrieval-Based Diagnostic Decision Support: Mixed Methods Study
# JMIR Med Inform 2024;12:e50209
# URL: https://medinform.jmir.org/2024/1/e50209
# doi: 10.2196/50209
# PMID: 38896468
# ©Tassallah Abdullahi, Laura Mercurio, Ritambhara Singh, Carsten Eickhoff. Originally published in JMIR Medical Informatics
# (https://medinform.jmir.org), 19.06.2024. This is an open-access article distributed under the terms of the Creative Commons
# Attribution License (https://creativecommons.org/licenses/by/4.0/), which permits unrestricted use, distribution, and reproduction
# in any medium, provided the original work, first published in JMIR Medical Informatics, is properly cited. The complete
# bibliographic information, a link to the original publication on https://medinform.jmir.org/, as well as this copyright and license
# information must be included.
# https://medinform.jmir.org/2024/1/e50209 JMIR Med Inform 2024 | vol. 12 | e50209 | p. 18
# XSL FO (page number not for citation purposes)
# •
# RenderX

# %%
# Prompt template
PROMPT_TEMPLATE = '''
You are assisting in finding potential information in a paper's content I provide you below. It's about to identify any content related to requirements for ai-based knowledge/information retrieval systems -> If the section or paper is not about IE/IR or similar -> not relevant! The objective is to identify places in the text that can contribute to any of the following predefined requirements: 
Organizational-Centric
1. Increased Productivity & Efficiency (f.x. solution enables time savings or ROI or similar.)
2. Performance Indicators / Measurability / Validation Metrics (Metrics/Test Data to validate solution.)
3. Organizational Acceptance (Any factors to achieve company acceptance like change management.)
4. Cost-Effectiveness (Releated to a positive cost-benefit ratio.)
User-Centric
5. User-Friendliness & Accessibility (f.x. intuitive access for all user skill levels.)
6. Natural Language Use (Enable conversational interactions in everyday language.)
7. Contextual Relevance & Awareness (Deliver precise, domain-specific answers tailored to context and user request.)
8. Feedback Mechanism (f.x. Incorporate stakeholders or users for initial planning or continuous improvement.)
9. Traceability & Transparency (f.x. Show sources and reasoning behind results to foster trust.)
10. Reasonable Response Times (Provide timely answers for an efficient user experience.)
Data-Centric
11. Data Integration / Handling Data Variety (Combine structured and unstructured data seamlessly / from different sources.)
12. Data Quality and Actuality (Are able to handle up-to-date and changing data.)
Tech-Centric
13. Integration Capability / Modularity (f.x. can be integrated and used within any workflows and systems / API-Design.)
14. Adaptability & Scalability (Support evolving demands and facilitate expansions.)
15. Security (f.x. mentions any security measures or standards.)
Legal and Ethical
16. Regulatory Compliance (Adhere to legal standards like GDPR or internal governance.)
17. Fairness & Bias (Ensure unbiased data handling and algorithmic outputs / mention anything about discrimination.)
18. Sustainability (f.x. Minimize environmental impact or ensure long-term viability.)

If found, please provide it like this (just an example data): 

(R2) Performance Indicators / Measurability / Validation: 
The paper discusses the validation of a retrieval system, indicating the need for metrics to assess its effectiveness. Also a suitable test data is needed as a quality metric to assist engineers and stakeholders for validation and expectation management. (p. 195).

(R7) Context Relevance: 
Paper describes the failure points of retrieval systems and the need to have a system that is designed to generate contextually relevant and accurate information. It describes that requests to unavailable content or requests for questions that are related to the content but don’t have answers the system could be fooled into giving a confusing response. (p.197)

(R9)Traceability:
The AITutor system proposed in the paper allows students to verify answers by a returned a source list, indicating it is required to support user by giving insights into how the system came to this solution (p. 196).

(R11) Data Integration / Handling Data Variety:
The paper mentions the need to process domain knowledge captured as artifacts in different formats, indicating the integration of various data types (p. 194). It shows the need to proper data handling, f.x. if the information lies in a certain format such as a table within the document. 

(R12) Data Quality and Actuality:
The paper highlights the importance of maintaining accurate and up-to-date information for reliable insights in an information retrieval systems (p. 195).

(R13) Integration Capability / Modularity:
The discussed AITutor system is integrated into the universities learning management system, showcasing its capability to integrate with existing workflows or systems (p. 196).

(R14) Adaptability & Scalability:
The paper discusses the need for retrieval systems to adapt to evolving demands and the importance of continuous adaptions (p. 198).

(R16) Regulatory Compliance: 
The study discusses compliance with privacy regulations (like f.x. GDPR) and the need to address these issues to ensure compliance with legal and ethical standards (p. 8).
(R18) Sustainability:
The discussion around the environmental impact of the suggest to minimize the footprint of such solutions (p. 195). 

The requirements not necessarily have to be in the exact wording as above, but should be clearly transferable to the predefined requirements. It's also ok to not find any of the requirements in the text. Usually no text can include all single requirements. A mentioned insight can also apply for multiple requirements.

The extracted paper's text: 
{text}
'''

# %%
# Prepare the prompt
prompt = PROMPT_TEMPLATE.format(text=pdf_text)

response = client.chat.completions.create(
    model=OPENAI_MODEL,
    messages=[
        {"role": "user", "content": prompt}
    ],
    n=1,
    temperature=0.1,
)
reply = response.choices[0].message.content

# Output the response
print(reply)
# Out:
# Here are the relevant extracts from the provided paper that align with the predefined requirements for AI-based knowledge/information retrieval systems:
#
# (R1) Increased Productivity & Efficiency:
# The study emphasizes that the CliniqIR framework enhances diagnostic quality by leveraging existing electronic health records and literature, which can lead to time savings in the diagnostic process and potentially improve return on investment (ROI) for healthcare systems (p. 1).
#
# (R2) Performance Indicators / Measurability / Validation Metrics:
# The paper discusses the evaluation of CliniqIR's performance using metrics such as mean reciprocal rank (MRR) to assess its effectiveness in predicting diagnoses, indicating the importance of measurable outcomes for validation (p. 10).
#
# (R3) Organizational Acceptance:
# The authors highlight the need for systems like CliniqIR to be user-friendly and transparent to foster trust among clinicians, which is crucial for organizational acceptance and integration into clinical workflows (p. 14).
#
# (R4) Cost-Effectiveness:
# The paper mentions that CliniqIR aims to improve diagnostic accuracy while maintaining economic feasibility, suggesting a positive cost-benefit ratio for its implementation in clinical settings (p. 2).
#
# (R5) User-Friendliness & Accessibility:
# CliniqIR is designed to be compatible with any information retrieval framework, which enhances its accessibility for clinicians with varying levels of technical expertise (p. 3).
#
# (R7) Contextual Relevance & Awareness:
# The framework utilizes clinical text records and external knowledge sources to deliver contextually relevant diagnoses, demonstrating its capability to provide precise, domain-specific answers tailored to clinical queries (p. 4).
#
# (R9) Traceability & Transparency:
# The CliniqIR system allows clinicians to trace back the sources of its diagnostic suggestions, fostering transparency and trust in the system's outputs (p. 14).
#
# (R11) Data Integration / Handling Data Variety:
# The paper discusses how CliniqIR integrates various data sources, including clinical text records and PubMed abstracts, to enhance its diagnostic capabilities, indicating its ability to handle diverse data types (p. 3).
#
# (R12) Data Quality and Actuality:
# The authors emphasize the importance of using up-to-date literature from PubMed to ensure that the information used for diagnosis is current and relevant (p. 4).
#
# (R13) Integration Capability / Modularity:
# CliniqIR is described as being adaptable to various information retrieval systems, showcasing its integration capability within existing clinical workflows (p. 3).
#
# (R14) Adaptability & Scalability:
# The framework is noted for its adaptability to different retrieval methods and its ability to scale across various clinical applications, which is essential for meeting evolving healthcare demands (p. 3).
#
# (R16) Regulatory Compliance:
# The study mentions the importance of adhering to legal standards in the development of diagnostic support systems, which is crucial for regulatory compliance (p. 8).
#
# (R18) Sustainability:
# The authors discuss the potential for CliniqIR to contribute to sustainable healthcare practices by improving diagnostic efficiency and reducing unnecessary procedures (p. 14).
#
# These extracts illustrate how the paper addresses various requirements for AI-based knowledge/information retrieval systems, particularly in the context of clinical decision support.
